# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql.window import Window
from pyspark.sql.types import StructType
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.sql.types import FloatType
from pyspark.sql.functions import udf, concat_ws, when, lit, count, isnan, col, isnull, substring, row_number

# %%
import os 
os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars /usr/share/java/mariadb-java-client-2.5.3.jar pyspark-shell'

# %%
spark_context = SparkContext()
sql_context = SQLContext(spark_context)
spark = sql_context.sparkSession

# %% [markdown]
# ## 1. Carga de datos

# %%
PATH = "./data/"

df_aeropuertos = spark.read.load(PATH+"aeropuertosEtapa3.csv",format="csv", sep=",", inferSchema="true", header="true")

df_vuelos = spark.read.load(PATH+"vuelosEtapa3.csv",format="csv", sep=",", inferSchema="true", header="true")

df_poblacion = spark.read.load(PATH+"poblacion2018.csv",format="csv", sep=",", inferSchema="true", header="true")

df_pib = spark.read.load(PATH+"pib_2019.csv",format="csv", sep=",", inferSchema="true", header="true")

df_aeropuertos_mundo= spark.read.load(PATH+"aeropuertos_mundo.csv",format="csv", sep=",", inferSchema="true", header="true")

# %% [markdown]
# ## 2. Perfilamiento

# %% [markdown]
# Tamaño de los dataframes

# %%
print((df_vuelos.count(), len(df_vuelos.columns)))
print((df_aeropuertos.count(), len(df_aeropuertos.columns)))
# Out:
# (96346, 13)
# (1461, 23)

# %%
df_aeropuertos.show(truncate=False, vertical = True)
# Out:
# -RECORD 0-------------------------------------------
#  sigla                | 7FO
#  iata                 | null
#  nombre               | LA ISLA
#  municipio            | Puerto Gaitán
#  departamento         | Meta
#  categoria            | Aeródromo
#  latitud              | 4.4211
#  longitud             | -71.6271
#  propietario          | LA ISLA Y EL ROSARIO S.A.
#  explotador           | LA CEIBA S.A.
#  longitud_pista       | 1079.0
#  ancho_pista          | 19.0
#  pbmo                 | 3000.0
#  elevacion            | 538.0
#  resolucion           |  1325,000
#  fecha_construccion   | 2015-06-05
#  fecha_vigencia       | 2018-06-11
#  clase                | 1A
#  tipo                 | Fumigación
#  numero_vuelos_origen | 2.0
#  gcd_departamento     | 50
#  gcd_municipio        | 50568
#  Ano                  | 2015
# -RECORD 1-------------------------------------------
#  sigla                | 7FO
#  iata                 | null
#  nombre               | LA ISLA
#  municipio            | Puerto Gaitán
#  departamento         | Meta
#  categoria            | Aeródromo
#  latitud              | 4.4211
#  longitud             | -71.6271
#  propietario          | LA ISLA Y EL ROSARIO S.A.
#  explotador           | LA CEIBA S.A.
#  longitud_pista       | 1321.0
#  ancho_pista          | 38.0
#  pbmo                 | 3000.0
#  elevacion            | 538.0
#  resolucion           |  1325,000
#  fecha_construccion   | 2015-06-05
#  fecha_vigencia       | 2018-06-11
#  clase                | 1A
#  tipo                 | Fumigación
#  numero_vuelos_origen | 2.0
#  gcd_departamento     | 50
#  gcd_municipio        | 50568
#  Ano                  | 2016
# -RECORD 2-------------------------------------------
#  sigla                | 7FU
#  iata                 | null
#  nombre               | LA ESCONDIDA
#  municipio            | Puerto Gaitán
#  departamento         | Meta
#  categoria            | Aeródromo
#  latitud              | 4.6108
#  longitud             | -71.1935
#  propietario          | PALMAS SICARARE S.A.S.
#  explotador           | COSARGO S.A.S.
#  longitud_pista       | 2141.0
#  ancho_pista          | 17.0
#  pbmo                 | 5000.0
#  elevacion            | 564.0
#  resolucion           |  1843,000
#  fecha_construccion   | 2013-04-26
#  fecha_vigencia       | 2016-05-07
#  clase                | 1A
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 24.0
#  gcd_departamento     | 50
#  gcd_municipio        | 50568
#  Ano                  | 2014
# -RECORD 3-------------------------------------------
#  sigla                | 7FU
#  iata                 | null
#  nombre               | LA ESCONDIDA
#  municipio            | Puerto Gaitán
#  departamento         | Meta
#  categoria            | Aeródromo
#  latitud              | 4.6108
#  longitud             | -71.1935
#  propietario          | PALMAS SICARARE S.A.S.
#  explotador           | COSARGO S.A.S.
#  longitud_pista       | 3853.0
#  ancho_pista          | 5.0
#  pbmo                 | 5000.0
#  elevacion            | 564.0
#  resolucion           |  1843,000
#  fecha_construccion   | 2013-04-26
#  fecha_vigencia       | 2016-05-07
#  clase                | 1A
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 24.0
#  gcd_departamento     | 50
#  gcd_municipio        | 50568
#  Ano                  | 2015
# -RECORD 4-------------------------------------------
#  sigla                | 7FU
#  iata                 | null
#  nombre               | LA ESCONDIDA
#  municipio            | Puerto Gaitán
#  departamento         | Meta
#  categoria            | Aeródromo
#  latitud              | 4.6108
#  longitud             | -71.1935
#  propietario          | PALMAS SICARARE S.A.S.
#  explotador           | COSARGO S.A.S.
#  longitud_pista       | 6667.0
#  ancho_pista          | 5.0
#  pbmo                 | 5000.0
#  elevacion            | 564.0
#  resolucion           |  1843,000
#  fecha_construccion   | 2013-04-26
#  fecha_vigencia       | 2016-05-07
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 12.0
#  gcd_departamento     | 50
#  gcd_municipio        | 50568
#  Ano                  | 2016
# -RECORD 5-------------------------------------------
#  sigla                | 7FW
#  iata                 | null
#  nombre               | MORICHITO
#  municipio            | Hato Corozal
#  departamento         | Casanare
#  categoria            | Aeródromo
#  latitud              | 5.9188
#  longitud             | -71.7932
#  propietario          | CARMEN NARANJO
#  explotador           | ROBERTO C. RIAÑO P.
#  longitud_pista       | 1361.0
#  ancho_pista          | 14.0
#  pbmo                 | 3500.0
#  elevacion            | 720.0
#  resolucion           |  2220,000
#  fecha_construccion   | 2009-05-07
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Privado
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 85
#  gcd_municipio        | 85125
#  Ano                  | 2014
# -RECORD 6-------------------------------------------
#  sigla                | 7FW
#  iata                 | null
#  nombre               | MORICHITO
#  municipio            | Hato Corozal
#  departamento         | Casanare
#  categoria            | Aeródromo
#  latitud              | 5.9188
#  longitud             | -71.7932
#  propietario          | CARMEN NARANJO
#  explotador           | ROBERTO C. RIAÑO P.
#  longitud_pista       | 1442.0
#  ancho_pista          | 4.0
#  pbmo                 | 3500.0
#  elevacion            | 720.0
#  resolucion           |  2220,000
#  fecha_construccion   | 2009-05-07
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Fumigación
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 85
#  gcd_municipio        | 85125
#  Ano                  | 2015
# -RECORD 7-------------------------------------------
#  sigla                | 7FW
#  iata                 | null
#  nombre               | MORICHITO
#  municipio            | Hato Corozal
#  departamento         | Casanare
#  categoria            | Aeródromo
#  latitud              | 5.9188
#  longitud             | -71.7932
#  propietario          | CARMEN NARANJO
#  explotador           | ROBERTO C. RIAÑO P.
#  longitud_pista       | 2411.0
#  ancho_pista          | 1.0
#  pbmo                 | 3500.0
#  elevacion            | 720.0
#  resolucion           |  2220,000
#  fecha_construccion   | 2009-05-07
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 85
#  gcd_municipio        | 85125
#  Ano                  | 2016
# -RECORD 8-------------------------------------------
#  sigla                | 7FX
#  iata                 | null
#  nombre               | CAROLINA DEL PRINCIPE
#  municipio            | Carolina
#  departamento         | Antioquia
#  categoria            | Aeródromo
#  latitud              | 6.7248
#  longitud             | -75.2909
#  propietario          | MUNICIPIO
#  explotador           | MUNICIPIO
#  longitud_pista       | 452.0
#  ancho_pista          | 0.0
#  pbmo                 | 1000.0
#  elevacion            | 6004.0
#  resolucion           |  6470,000
#  fecha_construccion   | 2013-11-19
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 5
#  gcd_municipio        | 5150
#  Ano                  | 2014
# -RECORD 9-------------------------------------------
#  sigla                | 7FX
#  iata                 | null
#  nombre               | CAROLINA DEL PRINCIPE
#  municipio            | Carolina
#  departamento         | Antioquia
#  categoria            | Aeródromo
#  latitud              | 6.7248
#  longitud             | -75.2909
#  propietario          | MUNICIPIO
#  explotador           | MUNICIPIO
#  longitud_pista       | 518.0
#  ancho_pista          | 0.0
#  pbmo                 | 1000.0
#  elevacion            | 6004.0
#  resolucion           |  6470,000
#  fecha_construccion   | 2013-11-19
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Fumigación
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 5
#  gcd_municipio        | 5150
#  Ano                  | 2015
# -RECORD 10------------------------------------------
#  sigla                | 7FX
#  iata                 | null
#  nombre               | CAROLINA DEL PRINCIPE
#  municipio            | Carolina
#  departamento         | Antioquia
#  categoria            | Aeródromo
#  latitud              | 6.7248
#  longitud             | -75.2909
#  propietario          | MUNICIPIO
#  explotador           | MUNICIPIO
#  longitud_pista       | 982.0
#  ancho_pista          | 0.0
#  pbmo                 | 1000.0
#  elevacion            | 6004.0
#  resolucion           |  6470,000
#  fecha_construccion   | 2013-11-19
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 5
#  gcd_municipio        | 5150
#  Ano                  | 2016
# -RECORD 11------------------------------------------
#  sigla                | 7FY
#  iata                 | null
#  nombre               | DUBAI
#  municipio            | Ayapel
#  departamento         | Córdoba
#  categoria            | Aeródromo
#  latitud              | 8.296
#  longitud             | -75.0307
#  propietario          | ANDRES D. LONDOÑO T.
#  explotador           | ANDRES D. LONDOÑO T.
#  longitud_pista       | 426.0
#  ancho_pista          | 15.0
#  pbmo                 | 500.0
#  elevacion            | 82.0
#  resolucion           |  1212,000
#  fecha_construccion   | 2013-03-20
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Fumigación
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 23
#  gcd_municipio        | 23068
#  Ano                  | 2014
# -RECORD 12------------------------------------------
#  sigla                | 7FY
#  iata                 | null
#  nombre               | DUBAI
#  municipio            | Ayapel
#  departamento         | Córdoba
#  categoria            | Aeródromo
#  latitud              | 8.296
#  longitud             | -75.0307
#  propietario          | ANDRES D. LONDOÑO T.
#  explotador           | ANDRES D. LONDOÑO T.
#  longitud_pista       | 814.0
#  ancho_pista          | 15.0
#  pbmo                 | 500.0
#  elevacion            | 82.0
#  resolucion           |  1212,000
#  fecha_construccion   | 2013-03-20
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 23
#  gcd_municipio        | 23068
#  Ano                  | 2015
# -RECORD 13------------------------------------------
#  sigla                | 7FY
#  iata                 | null
#  nombre               | DUBAI
#  municipio            | Ayapel
#  departamento         | Córdoba
#  categoria            | Aeródromo
#  latitud              | 8.296
#  longitud             | -75.0307
#  propietario          | ANDRES D. LONDOÑO T.
#  explotador           | ANDRES D. LONDOÑO T.
#  longitud_pista       | 1592.0
#  ancho_pista          | 21.0
#  pbmo                 | 500.0
#  elevacion            | 82.0
#  resolucion           |  1212,000
#  fecha_construccion   | 2013-03-20
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Privado
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 23
#  gcd_municipio        | 23068
#  Ano                  | 2016
# -RECORD 14------------------------------------------
#  sigla                | 7FZ
#  iata                 | null
#  nombre               | EL TRIUNFO
#  municipio            | Orocué
#  departamento         | Casanare
#  categoria            | Aeródromo
#  latitud              | 4.8095
#  longitud             | -71.667
#  propietario          | ERNESTO J. PEREZ VILLAMIZAR
#  explotador           | EL MISMO
#  longitud_pista       | 630.0
#  ancho_pista          | 25.0
#  pbmo                 | 3000.0
#  elevacion            | 475.0
#  resolucion           |  5532,000
#  fecha_construccion   | 2014-11-11
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Privado
#  numero_vuelos_origen | 2.0
#  gcd_departamento     | 85
#  gcd_municipio        | 85230
#  Ano                  | 2014
# -RECORD 15------------------------------------------
#  sigla                | 7FZ
#  iata                 | null
#  nombre               | EL TRIUNFO
#  municipio            | Orocué
#  departamento         | Casanare
#  categoria            | Aeródromo
#  latitud              | 4.8095
#  longitud             | -71.667
#  propietario          | ERNESTO J. PEREZ VILLAMIZAR
#  explotador           | EL MISMO
#  longitud_pista       | 363.0
#  ancho_pista          | 42.0
#  pbmo                 | 3000.0
#  elevacion            | 475.0
#  resolucion           |  5532,000
#  fecha_construccion   | 2014-11-11
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 2.0
#  gcd_departamento     | 85
#  gcd_municipio        | 85230
#  Ano                  | 2015
# -RECORD 16------------------------------------------
#  sigla                | 7FZ
#  iata                 | null
#  nombre               | EL TRIUNFO
#  municipio            | Orocué
#  departamento         | Casanare
#  categoria            | Aeródromo
#  latitud              | 4.8095
#  longitud             | -71.667
#  propietario          | ERNESTO J. PEREZ VILLAMIZAR
#  explotador           | EL MISMO
#  longitud_pista       | 5.0
#  ancho_pista          | 66.0
#  pbmo                 | 3000.0
#  elevacion            | 475.0
#  resolucion           |  5532,000
#  fecha_construccion   | 2014-11-11
#  fecha_vigencia       | null
#  clase                | 1A
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 2.0
#  gcd_departamento     | 85
#  gcd_municipio        | 85230
#  Ano                  | 2016
# -RECORD 17------------------------------------------
#  sigla                | 7GA
#  iata                 | null
#  nombre               | BARU - HIDROPUERTO
#  municipio            | Cartagena de Indias
#  departamento         | Bolívar
#  categoria            | Aeródromo
#  latitud              | 10.2321
#  longitud             | -75.5877
#  propietario          | MAURICIO E. VASQUEZ M.
#  explotador           | EL MISMO
#  longitud_pista       | 269.0
#  ancho_pista          | 27.0
#  pbmo                 | 500.0
#  elevacion            | 0.0
#  resolucion           |  6067,000
#  fecha_construccion   | 2012-10-25
#  fecha_vigencia       | 2015-11-07
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 13
#  gcd_municipio        | 13001
#  Ano                  | 2014
# -RECORD 18------------------------------------------
#  sigla                | 7GA
#  iata                 | null
#  nombre               | BARU - HIDROPUERTO
#  municipio            | Cartagena de Indias
#  departamento         | Bolívar
#  categoria            | Aeródromo
#  latitud              | 10.2321
#  longitud             | -75.5877
#  propietario          | MAURICIO E. VASQUEZ M.
#  explotador           | EL MISMO
#  longitud_pista       | 204.0
#  ancho_pista          | 46.0
#  pbmo                 | 500.0
#  elevacion            | 0.0
#  resolucion           |  6067,000
#  fecha_construccion   | 2012-10-25
#  fecha_vigencia       | 2015-11-07
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 13
#  gcd_municipio        | 13001
#  Ano                  | 2015
# -RECORD 19------------------------------------------
#  sigla                | 7GA
#  iata                 | null
#  nombre               | BARU - HIDROPUERTO
#  municipio            | Cartagena de Indias
#  departamento         | Bolívar
#  categoria            | Aeródromo
#  latitud              | 10.2321
#  longitud             | -75.5877
#  propietario          | MAURICIO E. VASQUEZ M.
#  explotador           | EL MISMO
#  longitud_pista       | 106.0
#  ancho_pista          | 69.0
#  pbmo                 | 500.0
#  elevacion            | 0.0
#  resolucion           |  6067,000
#  fecha_construccion   | 2012-10-25
#  fecha_vigencia       | 2015-11-07
#  clase                | 1A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 13
#  gcd_municipio        | 13001
#  Ano                  | 2016
# only showing top 20 rows

# %%
df_vuelos.show()
# Out:
# +----+---+------+-------+-----------+----------+-------+--------------------+------+------+--------------+---------+-----------+
# | ano|mes|origen|destino|tipo_equipo|tipo_vuelo|trafico|             empresa|vuelos|sillas|carga_ofrecida|pasajeros|carga_bordo|
# +----+---+------+-------+-----------+----------+-------+--------------------+------+------+--------------+---------+-----------+
# |2016| 11|   BOG|    MDE|       R722|         R|      N|                 LAS|     3|     0|       72000.0|        0|    60146.0|
# |2014|  2|   EOH|    BGA|       JS32|         R|      N|AEROLINEA DE ANTI...|    45|   766|      112220.0|      439|      999.0|
# |2017|  4|   VDF|    EOH|       C210|         T|      N|        HELI JET SAS|    15|     0|           0.0|       60|        0.0|
# |2018| 12|   PEI|    EOH|       C303|         T|      N|        HELI JET SAS|     4|     0|           0.0|        3|        0.0|
# |2018| 12|   LMC|    BOG|       JS32|         T|      N|         SARPA S.A.S|     2|     0|           0.0|        3|        0.0|
# |2010|  3|   UIB|    GIR|       JS32|         T|      N|         SARPA S.A.S|     1|     0|           0.0|        4|        0.0|
# |2011|  7|   UIB|    CLO|       L410|         T|      N|                 TAC|     2|     0|           0.0|       23|       32.0|
# |2011|  8|   ACD|    LCE|       C206|         T|      I|           AVIOCESAR|     1|     0|           0.0|        2|       62.0|
# |2014| 10|   CZU|    MTR|       C206|         T|      N|           AVIOCESAR|    16|     0|           0.0|       29|     1239.0|
# |2010|  1|   CDG|    BOG|       A343|         R|      I|          AIR FRANCE|    31|  8432|      310000.0|     7203|   197552.0|
# |2013| 10|   COG|    EOH|       C303|         T|      N|          TACA S.A.S|     1|     0|           0.0|        3|        0.0|
# |2018| 12|   SVI|    NVA|       C206|         T|      N| LLANERA DE AVIACION|     1|     0|           0.0|        0|        0.0|
# |2015|  1|   MVI|    MVP|       C206|         T|      N|AEROLINEAS LLANER...|     1|     0|           0.0|        0|        0.0|
# |2011|  3|   BOG|    BGI|       B762|         R|      I|    TAMPA CARGO S.A.|     4|     0|      163295.0|        0|   129721.0|
# |2011|  7|   BOG|    SVI|       D328|         R|      N|SERVICIO AEREO A ...|     9|   288|        6750.0|      119|        0.0|
# |2010|  4|   VVC|    CRU|       C182|         T|      N|                TARI|     1|     0|           0.0|        2|       97.0|
# |2018|  3|   BOG|    VGP|       B190|         T|      N|             HELICOL|     2|     0|           0.0|       10|        0.0|
# |2017|  1|   PCR|    VVC|       PA34|         T|      N|                SAER|     1|     0|           0.0|        2|      500.0|
# |2012|  3|   CUC|    MDE|       C414|         T|      N|AEROLINEAS ALAS D...|     2|     0|           0.0|        4|        0.0|
# |2014|  1|   EJA|    PCR|       B190|         T|      N|                 TAC|     1|     0|           0.0|        7|      318.0|
# +----+---+------+-------+-----------+----------+-------+--------------------+------+------+--------------+---------+-----------+
# only showing top 20 rows

# %% [markdown]
# #### Eliminación de duplicados y aeropuertos faltantes:

# %%
df_aeropuertos = df_aeropuertos.dropDuplicates()
df_vuelos = df_vuelos.dropDuplicates()
print((df_vuelos.count(), len(df_vuelos.columns)))
print((df_aeropuertos.count(), len(df_aeropuertos.columns)))
# Out:
# (96346, 13)
# (1461, 23)

# %%
df_ano = df_aeropuertos.groupby('sigla').pivot('Ano').count()
df_ano.select('*').where(isnull('2014')).show(100)
# Out:
# +-----+----+----+----+----+----+
# |sigla|2014|2015|2016|2017|2018|
# +-----+----+----+----+----+----+
# |  7IE|null|   1|   1|   1|   1|
# |  9DM|null|   1|   1|   1|   1|
# |  7IH|null|   1|   1|   1|   1|
# |  9AI|null|   1|   1|   1|   1|
# |  9NG|null|   1|   1|   1|   1|
# |  9AA|null|   1|   1|   1|   1|
# |  AMB|null|   1|   1|   1|   1|
# |  AGI|null|   1|   1|   1|   1|
# |  7II|null|   1|   1|   1|   1|
# |  9NI|null|   1|   1|   1|   1|
# |  9NF|null|   1|   1|   1|   1|
# |  7GL|null|   1|   1|   1|   1|
# |  7IG|null|   1|   1|   1|   1|
# |  9DK|null|   1|   1|   1|   1|
# |  9ND|null|   1|   1|   1|   1|
# |  9NK|null|   1|   1|   1|   1|
# |  9NL|null|   1|   1|   1|   1|
# |  9LZ|null|   1|   1|   1|   1|
# |  7IC|null|   1|   1|   1|   1|
# |  9NJ|null|   1|   1|   1|   1|
# |  7GZ|null|   1|   1|   1|   1|
# |  BAQ|null|   1|   1|   1|   1|
# |  9DA|null|   1|   1|   1|   1|
# |  9MB|null|   1|   1|   1|   1|
# |  9NC|null|   1|   1|   1|   1|
# |  7IJ|null|   1|   1|   1|   1|
# |  7ID|null|   1|   1|   1|   1|
# |  9CY|null|   1|   1|   1|   1|
# |  9NH|null|   1|   1|   1|   1|
# |  7FO|null|   1|   1|   1|   1|
# |  9NE|null|   1|   1|   1|   1|
# |  7GY|null|   1|   1|   1|   1|
# |  7IF|null|   1|   1|   1|   1|
# |  7HD|null|   1|   1|   1|   1|
# +-----+----+----+----+----+----+

# %%
#Se encuentra que Barranquilla no está en la actualización de 2014, sin embargo si tiene vuelos desde 2010 hasta 2014.
df_vuelos.select('*').where(df_vuelos['origen']=='BAQ').show(1000)
# Out:
# +----+---+------+-------+-----------+----------+-------+--------------------+------+------+--------------+---------+-----------+
# | ano|mes|origen|destino|tipo_equipo|tipo_vuelo|trafico|             empresa|vuelos|sillas|carga_ofrecida|pasajeros|carga_bordo|
# +----+---+------+-------+-----------+----------+-------+--------------------+------+------+--------------+---------+-----------+
# |2018|  3|   BAQ|    EOH|       C25C|         T|      N|             HELICOL|     2|     0|           0.0|        6|        0.0|
# |2015|  4|   BAQ|    MDE|       A318|         R|      N|             AVIANCA|     4|   400|       23241.0|      372|      490.0|
# |2010|  1|   BAQ|    CZU|       JS32|         R|      N|AEROLINEA DE ANTI...|    29|   568|        6838.0|      205|       66.0|
# |2011|  2|   BAQ|    BOG|       B722|         R|      N|           AEROSUCRE|     5|     0|      120000.0|        0|    52404.0|
# |2012|  4|   BAQ|    VUP|       PA34|         T|      N|           AVIOCESAR|     8|     0|           0.0|       16|      520.0|
# |2013|  2|   BAQ|    9BF|       BE20|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        6|      200.0|
# |2013|  5|   BAQ|    VUP|       PA34|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        4|        0.0|
# |2014| 12|   BAQ|    CUC|       JS32|         R|      N|AEROLINEA DE ANTI...|    32|   608|       45197.0|      379|      357.0|
# |2014|  1|   BAQ|    VUP|       PA31|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|       75.0|
# |2015| 11|   BAQ|    BOG|       E190|         R|      N|       AEROREPUBLICA|     1|   100|           0.0|       77|        0.0|
# |2015|  8|   BAQ|    BOG|       A320|         R|      N|   FAST COLOMBIA SAS|    29|  5220|           0.0|     4277|        0.0|
# |2016| 11|   BAQ|    RCH|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|      122.0|
# |2017|  9|   BAQ|    MDE|       A319|         A|      N|             AVIANCA|     1|   120|       12499.0|       29|        0.0|
# |2013| 12|   BAQ|    BOG|       A318|         R|      N|             AVIANCA|    32|  3199|      212988.0|     2631|    18496.0|
# |2010|  9|   BAQ|    BOG|        F10|         R|      N|             AVIANCA|    33|  3216|       69188.0|     2824|     6384.0|
# |2010|  2|   BAQ|    BOG|        F50|         R|      N|             AVIANCA|     1|    52|        5080.0|        0|        0.0|
# |2010|  2|   BAQ|    CTG|       E145|         A|      N|SERVICIO AEREO A ...|     1|    50|        1200.0|        1|        0.0|
# |2012|  2|   BAQ|    CTG|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        3|       75.0|
# |2013| 10|   BAQ|    RCH|       JS32|         R|      N|AEROLINEA DE ANTI...|    10|   190|       35999.0|       55|        0.0|
# |2013|  8|   BAQ|    BOG|       C550|         T|      N|           PETROLEUM|     1|     0|           0.0|        4|        0.0|
# |2013| 12|   BAQ|    MGN|       PA34|         T|      N|           AVIOCESAR|     2|     0|           0.0|        5|      139.0|
# |2014| 12|   BAQ|    ADZ|       A320|         C|      N|             AVIANCA|     1|   150|        2778.0|        0|        0.0|
# |2014|  5|   BAQ|    MGN|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        1|       65.0|
# |2014| 10|   BAQ|    RCH|       PA31|         T|      N|           AVIOCESAR|     1|     0|           0.0|        4|       15.0|
# |2014|  3|   BAQ|    BOG|       L410|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        3|      100.0|
# |2015|  4|   BAQ|    BOG|       A320|         A|      N|             AVIANCA|     1|   150|        5697.0|      150|        0.0|
# |2015|  5|   BAQ|    MMP|       PA34|         T|      N|           AVIOCESAR|     6|     0|           0.0|       10|      289.0|
# |2015| 10|   BAQ|    CZU|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|       12.0|
# |2015|  6|   BAQ|    BOG|       B190|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        2|       20.0|
# |2015|  2|   BAQ|    CUC|       C402|         T|      N|AEROCHARTER ANDIN...|     1|     0|           0.0|        8|       60.0|
# |2015|  9|   BAQ|    MGN|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        4|        0.0|
# |2016|  2|   BAQ|    BOG|       A320|         A|      N|             AVIANCA|     5|   749|       38728.0|      592|        0.0|
# |2016|  8|   BAQ|    ADZ|       E190|         R|      N|       AEROREPUBLICA|    12|  1182|       46296.0|      734|    10755.0|
# |2016|  4|   BAQ|    BOG|       A332|         R|      N|    TAMPA CARGO S.A.|     2|     0|      136000.0|        0|    56527.0|
# |2018|  9|   BAQ|    BOG|       B350|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        1|       10.0|
# |2011|  8|   BAQ|    BOG|       BE9L|         T|      N|             RIO SUR|     5|     0|           0.0|        2|        0.0|
# |2012|  7|   BAQ|    BOG|       A320|         R|      N|               AIRES|    31|  5208|        9211.0|     4314|     8266.0|
# |2012|  8|   BAQ|    BOG|       E190|         R|      N|       AEROREPUBLICA|    49|  5125|      506146.0|     4183|     6927.0|
# |2012| 10|   BAQ|    SMR|       L410|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        7|       40.0|
# |2012|  6|   BAQ|    VUP|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        2|        0.0|
# |2013|  3|   BAQ|    BOG|       A319|         A|      N|             AVIANCA|     3|   360|       18325.0|      333|      630.0|
# |2013|  1|   BAQ|    CTG|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        3|       60.0|
# |2013|  1|   BAQ|    VUP|       PA34|         T|      N|           AVIOCESAR|    14|     0|           0.0|       42|      840.0|
# |2013| 10|   BAQ|    IBE|       B350|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        2|       22.0|
# |2013| 10|   BAQ|    CTG|       C402|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        4|        0.0|
# |2013|  4|   BAQ|    EJA|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|
       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        0|        0.0|
# |2015| 11|   BAQ|    BOG|       A320|         C|      N|             AVIANCA|     5|   748|       49103.0|      421|        0.0|
# |2015|  1|   BAQ|    VUP|       PA34|         T|      N|           AVIOCESAR|    10|     0|           0.0|       19|      618.0|
# |2015| 11|   BAQ|    CTG|       PA31|         T|      N|           AVIOCESAR|     2|     0|           0.0|        4|       30.0|
# |2015|  5|   BAQ|    RCH|       C402|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        4|        0.0|
# |2016|  8|   BAQ|    BOG|       A318|         R|      N|             AVIANCA|    73|  7300|      340590.0|     6313|    28367.0|
# |2018|  9|   BAQ|    CLO|       A319|         R|      N|             AVIANCA|    17|  2040|        9142.0|     1687|     9142.0|
# |2010|  8|   BAQ|    BOG|        319|         R|      N|             AVIANCA|     1|   120|        6215.0|      116|      908.0|
# |2010|  2|   BAQ|    ADZ|       E190|         R|      N|       AEROREPUBLICA|    13|  1366|       27260.0|     1030|    14864.0|
# |2012|  4|   BAQ|    BOG|       A318|         R|      N|             AVIANCA|   104| 10413|      590033.0|     8903|    33372.0|
# |2013|  7|   BAQ|    CTG|       PA34|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        1|        0.0|
# |2015| 12|   BAQ|    BOG|       BE30|         T|      N|      INTEREJECUTIVA|     1|     0|           0.0|        0|        0.0|
# |2015|  2|   BAQ|    MMP|       PA34|         T|      N|           AVIOCESAR|     3|     0|           0.0|        5|      209.0|
# |2016|  5|   BAQ|    BOG|       A320|         R|      N|               AIRES|   125| 21750|     2437500.0|    16579|    37168.0|
# |2016| 10|   BAQ|    BOG|       A319|         R|      N|               AIRES|    26|  3744|      455000.0|     3435|     2888.0|
# |2016| 11|   BAQ|    BOG|       A319|         R|      N|               AIRES|    56|  8064|      980000.0|     7334|    11370.0|
# |2016| 10|   BAQ|    BOG|       A320|         C|      N|             AVIANCA|     1|   150|           0.0|        0|        0.0|
# |2016|  7|   BAQ|    ADZ|       E190|         R|      N|       AEROREPUBLICA|    12|  1200|       29090.0|      980|    10962.0|
# |2016|  2|   BAQ|    CTG|       PA31|         T|      N|           AVIOCESAR|     1|     0|           0.0|        3|       35.0|
# |2011|  6|   BAQ|    VUP|       B350|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        9|       23.0|
# |2015|  1|   BAQ|    CLO|       A320|         R|      N|             AVIANCA|    44|  6598|      331835.0|     5526|    22865.0|
# |2012| 10|   BAQ|    VUP|       C402|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        6|        0.0|
# |2010| 12|   BAQ|    BOG|       B737|         R|      N|               AIRES|   111| 16428|        3229.0|    10762|     3229.0|
# |2010|  3|   BAQ|    ELB|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        6|        0.0|
# |2011|  8|   BAQ|    MMP|       C182|         T|      N|           AVIOCESAR|     2|     0|           0.0|        4|      124.0|
# |2013|  7|   BAQ|    VUP|       JS41|         R|      N|         EASYFLY S.A|    22|   660|           0.0|      535|        0.0|
# |2013|  8|   BAQ|    ADZ|       B190|         T|      N|         SEARCA S.A.|     1|     0|           0.0|       17|      285.0|
# |2014|  9|   BAQ|    CUC|       JS32|         R|      N|AEROLINEA DE ANTI...|    30|   570|       42106.0|      251|      208.0|
# |2014|  3|   BAQ|    BOG|       B737|         R|      N|               AIRES|     5|   740|       12500.0|      641|     2257.0|
# |2014| 10|   BAQ|    RCH|       A320|         R|      N|             AVIANCA|     1|   150|        6546.0|      100|        0.0|
# |2014|  1|   BAQ|    BOG|       B732|         R|      N|           AEROSUCRE|     1|     0|       15000.0|        0|     9859.0|
# |2014| 10|   BAQ|    CZU|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|      100.0|
# |2014|  2|   BAQ|    RCH|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        6|        0.0|
# |2014| 11|   BAQ|    7GL|       C402|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        4|        0.0|
# |2015| 11|   BAQ|    BOG|       A320|         R|      N|             AVIANCA|   278| 41689|     1890722.0|    35678|   145799.0|
# |2015| 12|   BAQ|    MTR|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|       15.0|
# |2016|  2|   BAQ|    CLO|       A320|         R|      N|               AIRES|     1|   174|       19500.0|      152|        0.0|
# |2016| 12|   BAQ|    BOG|       A320|         R|      N|               AIRES|    57|  9882|     1111500.0|     7886|    16850.0|
# |2016|  5|   BAQ|    BOG|       A320|         R|      N|   FAST COLOMBIA SAS|    25|  4500|           0.0|     3886|        0.0|
# |2016|  3|   BAQ|    CTG|       PA31|         T|      N|           AVIOCESAR|     3|     0|           0.0|        5|      328.0|
# |2014|  9|   BAQ|    LLO|       L410|         T|      N|         SEARCA S.A.|    32|     0|           0.0|      446|     1805.0|
# |2012|  9|   BAQ|    BVA|       PA31|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|
         T|      N|         SEARCA S.A.|     1|     0|           0.0|        2|        0.0|
# |2011|  7|   BAQ|    MTR|       AN32|         T|      N| AER CARIBE LIMITADA|     1|     0|           0.0|        0|     4000.0|
# |2012|  5|   BAQ|    BOG|       A320|         R|      N|               AIRES|    46|  7728|       13669.0|     4138|     9487.0|
# |2012|  1|   BAQ|    BOG|       B722|         R|      N|           AEROSUCRE|    12|     0|      288000.0|        0|   194428.0|
# |2012|  7|   BAQ|    ADZ|       E190|         R|      N|       AEROREPUBLICA|    13|  1366|      123113.0|     1118|    15639.0|
# |2012|  7|   BAQ|    SMR|       PA31|         T|      N|           AVIOCESAR|     2|     0|           0.0|        5|      148.0|
# |2012|  5|   BAQ|    CTG|       B190|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        1|        1.0|
# |2013|  8|   BAQ|    BOG|       B732|         R|      N|           AEROSUCRE|     3|     0|       45000.0|        0|    28382.0|
# |2013|  6|   BAQ|    BOG|       BE40|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        8|        0.0|
# |2013|  8|   BAQ|    BOG|       AN32|         T|      N| AER CARIBE LIMITADA|     1|     0|           0.0|        0|     2000.0|
# |2014|  6|   BAQ|    VUP|       JS41|         R|      N|         EASYFLY S.A|    36|  1080|           0.0|      778|        0.0|
# |2014| 11|   BAQ|    BOG|       B722|         R|      N|           AEROSUCRE|    14|     0|      336000.0|        0|   272002.0|
# |2014|  2|   BAQ|    VUP|       BE30|         T|      N|      INTEREJECUTIVA|     1|     0|           0.0|        7|        0.0|
# |2014|  7|   BAQ|    ELB|       PA31|         T|      N|           AVIOCESAR|     1|     0|           0.0|        1|       85.0|
# |2015|  3|   BAQ|    BOG|       B350|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        4|       30.0|
# |2016|  8|   BAQ|    BOG|       A320|         R|      N|             AVIANCA|   254| 38096|     1485120.0|    32798|   135091.0|
# |2016| 12|   BAQ|    BOG|       B722|         R|      N|           AEROSUCRE|    22|     0|      528000.0|        0|   425984.0|
# |2016|  3|   BAQ|    ADZ|       E190|         R|      N|       AEROREPUBLICA|    13|  1300|       29281.0|     1092|     9821.0|
# |2017|  7|   BAQ|    MTB|       C421|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        2|        0.0|
# |2010|  8|   BAQ|    MTR|       DH8D|         R|      N|               AIRES|    37|  1369|        8523.0|      812|     1849.0|
# |2011|  4|   BAQ|    BOG|       B721|         R|      N|           AEROSUCRE|     8|     0|      168000.0|        0|    94279.0|
# |2012|  6|   BAQ|    CLO|       A318|         R|      N|             AVIANCA|    18|  1800|      137504.0|     1232|     6271.0|
# |2012|  6|   BAQ|    ADZ|       E190|         R|      N|       AEROREPUBLICA|    13|  1379|      123951.0|     1253|    13631.0|
# |2013|  8|   BAQ|    BOG|       BE40|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        3|        0.0|
# |2013|  4|   BAQ|    CUC|       PA34|         T|      N|         TAXCO S.A.S|     1|     0|           0.0|        4|       50.0|
# |2013|  9|   BAQ|    EJA|       C402|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        6|        0.0|
# |2016|  1|   BAQ|    CUC|       JS32|         R|      N|AEROLINEA DE ANTI...|    30|   570|       41939.0|      301|      204.0|
# |2016|  2|   BAQ|    BOG|       A318|         R|      N|             AVIANCA|    81|  8085|      481908.0|     7017|    53976.0|
# |2016|  1|   BAQ|    CLO|       B722|         R|      N|           AEROSUCRE|     1|     0|       24000.0|        0|    17285.0|
# |2016|  1|   BAQ|    BOG|       B722|         R|      N|                 LAS|     3|     0|       72000.0|        0|    23440.0|
# |2016| 10|   BAQ|    9NB|       PA31|         T|      N|           AVIOCESAR|     1|     0|           0.0|        3|      180.0|
# |2016|  1|   BAQ|    BOG|       HAWK|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        0|        0.0|
# |2018|  6|   BAQ|    BOG|       B788|         R|      N|             AVIANCA|     1|   250|           0.0|      245|        0.0|
# |2016|  9|   BAQ|    MDE|       B721|         R|      N|                 LAS|     1|     0|       19000.0|        0|     8101.0|
# |2017| 11|   BAQ|    MGN|       C421|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|
         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|       62.0|
# |2011| 11|   BAQ|    VUP|       C182|         T|      N|           AVIOCESAR|     1|     0|           0.0|        3|       62.0|
# |2012| 10|   BAQ|    9BF|       PA34|         T|      N|           AVIOCESAR|     4|     0|           0.0|        8|      304.0|
# |2012|  7|   BAQ|    BOG|       AC90|         T|      N| LLANERA DE AVIACION|     1|     0|           0.0|        3|        0.0|
# |2013|  6|   BAQ|    BOG|       A320|         R|      N|               AIRES|    79| 13746|      276500.0|    11111|    68929.0|
# |2013|  5|   BAQ|    BOG|       A319|         R|      N|             AVIANCA|    25|  3000|      196901.0|     2340|     6705.0|
# |2013|  5|   BAQ|    CLO|       A319|         R|      N|             AVIANCA|     3|   360|       30116.0|      238|     1456.0|
# |2013| 10|   BAQ|    RCH|       PA34|         T|      N|           AVIOCESAR|    12|     0|           0.0|       24|      828.0|
# |2013| 12|   BAQ|    BOG|       B190|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        2|      510.0|
# |2013| 11|   BAQ|    CTG|       HAWK|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        1|        0.0|
# |2013|  6|   BAQ|    MMP|       PA34|         T|      N|         TAXCO S.A.S|     1|     0|           0.0|        2|      120.0|
# |2013|  8|   BAQ|    VUP|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        3|        0.0|
# |2015| 12|   BAQ|    BOG|       A320|         R|      N|   FAST COLOMBIA SAS|    27|  4860|           0.0|     4223|        0.0|
# |2015|  7|   BAQ|    CZU|       C402|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        0|        0.0|
# |2016|  7|   BAQ|    MTR|       JS41|         R|      N|         EASYFLY S.A|    49|  1470|           0.0|      980|        0.0|
# |2016|  5|   BAQ|    BAQ|       PA34|         T|      N|           AVIOCESAR|     2|     0|           0.0|        2|       82.0|
# |2016|  9|   BAQ|    MDE|        332|         R|      N|    TAMPA CARGO S.A.|     3|     0|      204000.0|        0|    32337.0|
# |2013|  9|   BAQ|    LIM|       A320|         C|      I|TRANS AMERICAN AI...|     1|   150|           0.0|       67|        0.0|
# |2016|  6|   BAQ|    MTR|       JS41|         R|      N|         EASYFLY S.A|    57|  1709|           0.0|     1110|        0.0|
# |2010|  5|   BAQ|    CZU|       JS32|         R|      N|AEROLINEA DE ANTI...|    23|   428|        5196.0|       76|      242.0|
# |2011|  3|   BAQ|    BOG|       B737|         R|      N|          C.V. CARGO|    18|     0|      242532.0|        0|   170609.0|
# |2011|  1|   BAQ|    AUC|       C172|         T|      N|AEROLINEAS ALAS D...|     2|     0|           0.0|        4|        0.0|
# |2012|  9|   BAQ|    BOG|       A320|         R|      N|               AIRES|     8|  1344|       28000.0|      930|     3034.0|
# |2013|  8|   BAQ|    BOG|       A320|         R|      N|               AIRES|    66| 11484|      231000.0|     8068|    47312.0|
# |2013| 12|   BAQ|    EJA|       PA34|         T|      N|           AVIOCESAR|     1|     0|           0.0|        3|       72.0|
# |2013|  2|   BAQ|    VUP|       C414|         T|      N|AEROLINEAS ALAS D...|     1|     0|           0.0|        2|        0.0|
# |2013|  1|   BAQ|    GYM|       PA34|         T|      N|         TAXCO S.A.S|     1|     0|           0.0|        2|       50.0|
# |2014|  9|   BAQ|    BOG|       A320|         R|      N|             AVIANCA|   312| 46803|     2871362.0|    31973|   162144.0|
# |2015|  7|   BAQ|    CLO|       A319|         R|      N|             AVIANCA|     2|   240|       12665.0|      227|     2483.0|
# |2015| 12|   BAQ|    CLO|       A320|         R|      N|             AVIANCA|    45|  6748|      335025.0|     5734|    44561.0|
# |2015|  1|   BAQ|    VUP|       PA31|         T|      N|           AVIOCESAR|    12|     0|           0.0|       25|      861.0|
# |2015|  7|   BAQ|    ADZ|       L410|         T|      N|         SEARCA S.A.|     1|     0|           0.0|
# |2012|  3|   BAQ|    SMR|       PA34|         T|      N|           AVIOCESAR|     3|     0|           0.0|        6|      219.0|
# |2013|  9|   BAQ|    BOG|       A319|         R|      N|             AVIANCA|    19|  2280|       70661.0|     2025|     7066.0|
# |2013|  3|   BAQ|    CTG|       C206|         T|      N|           AVIOCESAR|     1|     0|           0.0|        2|       67.0|
# |2014| 10|   BAQ|    ELB|       PA34|         T|      N|           AVIOCESAR|     2|     0|           0.0|        4|       38.0|
# |2015|  7|   BAQ|    BOG|       A320|         R|      N|               AIRES|   139| 24186|     2710500.0|    20696|    36779.0|
# |2015|  3|   BAQ|    BOG|       R722|         R|      N|                 LAS|     1|     0|       24000.0|        0|      538.0|
# |2015| 12|   BAQ|    MMP|       PA34|         T|      N|           AVIOCESAR|     7|     0|           0.0|       10|      247.0|
# |2016|  4|   BAQ|    BOG|       A318|         R|      N|             AVIANCA|    60|  5992|      377056.0|     4860|    23530.0|
# |2016|  7|   BAQ|    BOG|       B722|         R|      N|                 LAS|     8|     0|      192000.0|        0|    86417.0|
# |2015|  9|   BAQ|    LLO|       L410|         T|      N|         SEARCA S.A.|     1|     0|           0.0|       15|       85.0|
# |2013|  9|   BAQ|    CTG|       PA31|         T|      N|           AVIOCESAR|     2|     0|           0.0|        5|      141.0|
# |2010|  7|   BAQ|    SMR|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        1|        0.0|
# |2016|  6|   BAQ|    MDE|       A320|         R|      N|             AVIANCA|    78| 11694|      518635.0|    10387|    33878.0|
# |2010| 12|   BAQ|    BOG|       B350|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        0|       23.0|
# |2011| 12|   BAQ|    BOG|       B722|         R|      N|                 LAS|     7|     0|      119966.0|        0|   118308.0|
# |2011| 12|   BAQ|    BOG|       E190|         R|      N|       AEROREPUBLICA|    56|  5648|      621359.0|     4088|    12335.0|
# |2011|  7|   BAQ|    CTG|       PA34|         T|      N|           AVIOCESAR|     4|     0|           0.0|        8|      300.0|
# |2011|  2|   BAQ|    VUP|       PA31|         T|      N|CHARTER DEL CARIB...|     1|     0|           0.0|        4|        0.0|
# |2012|  9|   BAQ|    VUP|       JS41|         R|      N|         EASYFLY S.A|     7|   210|           0.0|      138|        0.0|
# |2012|  8|   BAQ|    BOG|       L410|         T|      N|         SEARCA S.A.|     1|     0|           0.0|        0|       20.0|
# +----+---+------+-------+-----------+----------+-------+--------------------+------+------+--------------+---------+-----------+
# only showing top 1000 rows

# %%
#Se encuentra que el aeropuerta de CUC tiene dos registros por actualización. Se elimina una observación en cada año.

df_aeropuertos.select('*').where(df_aeropuertos['sigla']=='CUC').show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 4768.0
#  ancho_pista          | 30.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Fumigación
#  numero_vuelos_origen | 204319.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2018
# -RECORD 1------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 2782.0
#  ancho_pista          | 60.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 124815.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2014
# -RECORD 2------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA No.2
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 5337.0
#  ancho_pista          | 7.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4A
#  tipo                 | Fumigación
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2018
# -RECORD 3------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA No.2
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 1131.0
#  ancho_pista          | 2.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2014
# -RECORD 4------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA No.2
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 3790.0
#  ancho_pista          | 20.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4A
#  tipo                 | Público
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2017
# -RECORD 5------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 5359.0
#  ancho_pista          | 159.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Público
#  numero_vuelos_origen | 254999.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2016
# -RECORD 6------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA No.2
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 129.0
#  ancho_pista          | 0.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4A
#  tipo                 | Privado
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2016
# -RECORD 7------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 3484.0
#  ancho_pista          | 120.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Público
#  numero_vuelos_origen | 160599.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2015
# -RECORD 8------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 3718.0
#  ancho_pista          | 30.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Fumigación
#  numero_vuelos_origen | 132445.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2017
# -RECORD 9------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA No.2
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 574.0
#  ancho_pista          | 0.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4A
#  tipo                 | Privado
#  numero_vuelos_origen | 0.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2015

# %%
df_aeropuertos = df_aeropuertos.filter(df_aeropuertos['nombre'] != 'CAMILO DAZA No.2')
#df_aeropuertos = df_aeropuertos.dropDuplicates(['sigla','Ano'])
df_aeropuertos.select('*').where(df_aeropuertos['sigla']=='CUC').show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 4768.0
#  ancho_pista          | 30.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Fumigación
#  numero_vuelos_origen | 204319.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2018
# -RECORD 1------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 2782.0
#  ancho_pista          | 60.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Aerocivil
#  numero_vuelos_origen | 124815.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2014
# -RECORD 2------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 5359.0
#  ancho_pista          | 159.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Público
#  numero_vuelos_origen | 254999.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2016
# -RECORD 3------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 3484.0
#  ancho_pista          | 120.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Público
#  numero_vuelos_origen | 160599.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2015
# -RECORD 4------------------------------------
#  sigla                | CUC
#  iata                 | CUC
#  nombre               | CAMILO DAZA
#  municipio            | San José de Cúcuta
#  departamento         | Norte de Santander
#  categoria            | Internacional
#  latitud              | 7.9274
#  longitud             | -72.5116
#  propietario          | AEROCIVIL
#  explotador           | AEROCIVIL -ORIENT...
#  longitud_pista       | 3718.0
#  ancho_pista          | 30.0
#  pbmo                 | null
#  elevacion            | 1027.0
#  resolucion           |   984,000
#  fecha_construccion   | 1987-02-02
#  fecha_vigencia       | null
#  clase                | 4D
#  tipo                 | Fumigación
#  numero_vuelos_origen | 132445.0
#  gcd_departamento     | 54
#  gcd_municipio        | 54001
#  Ano                  | 2017

# %%
print((df_aeropuertos.count(), len(df_aeropuertos.columns)))
# Out:
# (1456, 23)

# %%
#Se encuentra que Bogota esta clasificado como Fumigación en 2014, 2015 y 2017, Privado en 2016 y Público en 2018.
df_aeropuertos.select('*').where(df_aeropuertos['sigla']=='BOG').show(truncate = False)
# Out:
# +-----+----+---------+------------+------------+-------------+-------+--------+-----------+------------------+--------------+-----------+----+---------+----------+------------------+--------------+-----+----------+--------------------+----------------+-------------+----+
# |sigla|iata|nombre   |municipio   |departamento|categoria    |latitud|longitud|propietario|explotador        |longitud_pista|ancho_pista|pbmo|elevacion|resolucion|fecha_construccion|fecha_vigencia|clase|tipo      |numero_vuelos_origen|gcd_departamento|gcd_municipio|Ano |
# +-----+----+---------+------------+------------+-------------+-------+--------+-----------+------------------+--------------+-----------+----+---------+----------+------------------+--------------+-----+----------+--------------------+----------------+-------------+----+
# |BOG  |BOG |EL DORADO|Bogotá, D.C.|Bogotá, D.C.|Internacional|4.7017 |-74.1469|AEROCIVIL  |EN CONCESION CODAD|4083.0        |35.0       |null|8356.0   |  320,000 |1959-12-04        |null          |4E   |Fumigación|1399777.0           |11              |11001        |2014|
# |BOG  |BOG |EL DORADO|Bogotá, D.C.|Bogotá, D.C.|Internacional|4.7017 |-74.1469|AEROCIVIL  |EN CONCESION CODAD|4572.0        |33.0       |null|8356.0   |  320,000 |1959-12-04        |null          |4E   |Fumigación|2574632.0           |11              |11001        |2015|
# |BOG  |BOG |EL DORADO|Bogotá, D.C.|Bogotá, D.C.|Internacional|4.7017 |-74.1469|AEROCIVIL  |EN CONCESION CODAD|6567.0        |6.0        |null|8356.0   |  320,000 |1959-12-04        |null          |4E   |Público   |396522.0            |11              |11001        |2018|
# |BOG  |BOG |EL DORADO|Bogotá, D.C.|Bogotá, D.C.|Internacional|4.7017 |-74.1469|AEROCIVIL  |EN CONCESION CODAD|6516.0        |14.0       |null|8356.0   |  320,000 |1959-12-04        |null          |4E   |Fumigación|811607.0            |11              |11001        |2017|
# |BOG  |BOG |EL DORADO|Bogotá, D.C.|Bogotá, D.C.|Internacional|4.7017 |-74.1469|AEROCIVIL  |EN CONCESION CODAD|5751.0        |13.0       |null|8356.0   |  320,000 |1959-12-04        |null          |4E   |Privado   |5057074.0           |11              |11001        |2016|
# +-----+----+---------+------------+------------+-------------+-------+--------+-----------+------------------+--------------+-----------+----+---------+----------+------------------+--------------+-----+----------+--------------------+----------------+-------------+----+

# %% [markdown]
# #### Valores nulos:

# %%
df_aeropuertos.select([count(when(isnull(c), c)).alias(c) for c in df_aeropuertos.columns]).show(truncate = False, vertical = True)
# Out:
# -RECORD 0--------------------
#  sigla                | 0
#  iata                 | 1138
#  nombre               | 0
#  municipio            | 0
#  departamento         | 0
#  categoria            | 0
#  latitud              | 0
#  longitud             | 0
#  propietario          | 10
#  explotador           | 0
#  longitud_pista       | 0
#  ancho_pista          | 0
#  pbmo                 | 233
#  elevacion            | 0
#  resolucion           | 19
#  fecha_construccion   | 0
#  fecha_vigencia       | 1078
#  clase                | 0
#  tipo                 | 0
#  numero_vuelos_origen | 0
#  gcd_departamento     | 0
#  gcd_municipio        | 0
#  Ano                  | 0

# %%
df_vuelos.select([count(when(isnull(c), c)).alias(c) for c in df_vuelos.columns]).show(truncate = False, vertical = True)
# Out:
# -RECORD 0-------------
#  ano            | 0
#  mes            | 0
#  origen         | 0
#  destino        | 0
#  tipo_equipo    | 0
#  tipo_vuelo     | 0
#  trafico        | 0
#  empresa        | 0
#  vuelos         | 0
#  sillas         | 0
#  carga_ofrecida | 0
#  pasajeros      | 0
#  carga_bordo    | 2

# %%
#Valores descriptivos para características de aeropuertos

df_aeropuertos.select('longitud_pista', 'ancho_pista').describe().show()
# Out:
# +-------+------------------+------------------+
# |summary|    longitud_pista|       ancho_pista|
# +-------+------------------+------------------+
# |  count|              1456|              1456|
# |   mean|1141.4120879120878|21.732142857142858|
# | stddev|1377.1186116731806|24.370501233824164|
# |    min|               0.0|               0.0|
# |    max|           12279.0|             169.0|
# +-------+------------------+------------------+

# %% [markdown]
# ## 3. Transformaciones

# %% [markdown]
# #### Dimension Fecha

# %%
def creacion_fecha(df_vuelos):
    
    df_fecha = df_vuelos.select('ano','mes')
    
    df_fecha = df_fecha.withColumn("mes", f.format_string("%02d","mes"))
    df_fecha = df_fecha.select(concat_ws('-','ano','mes').alias('Key_Fecha'),'ano','mes')
    df_fecha = df_fecha.dropDuplicates(['Key_Fecha'])
    df_fecha = df_fecha.sort('Key_Fecha')
    df_fecha = df_fecha.withColumn('Mes_nombre', when(df_fecha.mes == 1, lit('Enero'))
                                                .when(df_fecha.mes == 2, lit('Febrero'))
                                                .when(df_fecha.mes == 3, lit('Marzo'))
                                                .when(df_fecha.mes == 4, lit('Abril'))
                                                .when(df_fecha.mes == 5, lit('Mayo'))
                                                .when(df_fecha.mes == 6, lit('Junio'))
                                                .when(df_fecha.mes == 7, lit('Julio'))
                                                .when(df_fecha.mes == 8, lit('Agosto'))
                                                .when(df_fecha.mes == 9, lit('Septiembre'))
                                                .when(df_fecha.mes == 10, lit('Octubre'))
                                                .when(df_fecha.mes == 11, lit('Noviembre'))
                                                .when(df_fecha.mes == 12, lit('Diciembre'))
                                    )
    
    
    
    df_fecha.show(108)

    return df_fecha
    
df_fecha = creacion_fecha(df_vuelos)
# Out:
# +---------+----+---+----------+
# |Key_Fecha| ano|mes|Mes_nombre|
# +---------+----+---+----------+
# |  2010-01|2010| 01|     Enero|
# |  2010-02|2010| 02|   Febrero|
# |  2010-03|2010| 03|     Marzo|
# |  2010-04|2010| 04|     Abril|
# |  2010-05|2010| 05|      Mayo|
# |  2010-06|2010| 06|     Junio|
# |  2010-07|2010| 07|     Julio|
# |  2010-08|2010| 08|    Agosto|
# |  2010-09|2010| 09|Septiembre|
# |  2010-10|2010| 10|   Octubre|
# |  2010-11|2010| 11| Noviembre|
# |  2010-12|2010| 12| Diciembre|
# |  2011-01|2011| 01|     Enero|
# |  2011-02|2011| 02|   Febrero|
# |  2011-03|2011| 03|     Marzo|
# |  2011-04|2011| 04|     Abril|
# |  2011-05|2011| 05|      Mayo|
# |  2011-06|2011| 06|     Junio|
# |  2011-07|2011| 07|     Julio|
# |  2011-08|2011| 08|    Agosto|
# |  2011-09|2011| 09|Septiembre|
# |  2011-10|2011| 10|   Octubre|
# |  2011-11|2011| 11| Noviembre|
# |  2011-12|2011| 12| Diciembre|
# |  2012-01|2012| 01|     Enero|
# |  2012-02|2012| 02|   Febrero|
# |  2012-03|2012| 03|     Marzo|
# |  2012-04|2012| 04|     Abril|
# |  2012-05|2012| 05|      Mayo|
# |  2012-06|2012| 06|     Junio|
# |  2012-07|2012| 07|     Julio|
# |  2012-08|2012| 08|    Agosto|
# |  2012-09|2012| 09|Septiembre|
# |  2012-10|2012| 10|   Octubre|
# |  2012-11|2012| 11| Noviembre|
# |  2012-12|2012| 12| Diciembre|
# |  2013-01|2013| 01|     Enero|
# |  2013-02|2013| 02|   Febrero|
# |  2013-03|2013| 03|     Marzo|
# |  2013-04|2013| 04|     Abril|
# |  2013-05|2013| 05|      Mayo|
# |  2013-06|2013| 06|     Junio|
# |  2013-07|2013| 07|     Julio|
# |  2013-08|2013| 08|    Agosto|
# |  2013-09|2013| 09|Septiembre|
# |  2013-10|2013| 10|   Octubre|
# |  2013-11|2013| 11| Noviembre|
# |  2013-12|2013| 12| Diciembre|
# |  2014-01|2014| 01|     Enero|
# |  2014-02|2014| 02|   Febrero|
# |  2014-03|2014| 03|     Marzo|
# |  2014-04|2014| 04|     Abril|
# |  2014-05|2014| 05|      Mayo|
# |  2014-06|2014| 06|     Junio|
# |  2014-07|2014| 07|     Julio|
# |  2014-08|2014| 08|    Agosto|
# |  2014-09|2014| 09|Septiembre|
# |  2014-10|2014| 10|   Octubre|
# |  2014-11|2014| 11| Noviembre|
# |  2014-12|2014| 12| Diciembre|
# |  2015-01|2015| 01|     Enero|
# |  2015-02|2015| 02|   Febrero|
# |  2015-03|2015| 03|     Marzo|
# |  2015-04|2015| 04|     Abril|
# |  2015-05|2015| 05|      Mayo|
# |  2015-06|2015| 06|     Junio|
# |  2015-07|2015| 07|     Julio|
# |  2015-08|2015| 08|    Agosto|
# |  2015-09|2015| 09|Septiembre|
# |  2015-10|2015| 10|   Octubre|
# |  2015-11|2015| 11| Noviembre|
# |  2015-12|2015| 12| Diciembre|
# |  2016-01|2016| 01|     Enero|
# |  2016-02|2016| 02|   Febrero|
# |  2016-03|2016| 03|     Marzo|
# |  2016-04|2016| 04|     Abril|
# |  2016-05|2016| 05|      Mayo|
# |  2016-06|2016| 06|     Junio|
# |  2016-07|2016| 07|     Julio|
# |  2016-08|2016| 08|    Agosto|
# |  2016-09|2016| 09|Septiembre|
# |  2016-10|2016| 10|   Octubre|
# |  2016-11|2016| 11| Noviembre|
# |  2016-12|2016| 12| Diciembre|
# |  2017-01|2017| 01|     Enero|
# |  2017-02|2017| 02|   Febrero|
# |  2017-03|2017| 03|     Marzo|
# |  2017-04|2017| 04|     Abril|
# |  2017-05|2017| 05|      Mayo|
# |  2017-06|2017| 06|     Junio|
# |  2017-07|2017| 07|     Julio|
# |  2017-08|2017| 08|    Agosto|
# |  2017-09|2017| 09|Septiembre|
# |  2017-10|2017| 10|   Octubre|
# |  2017-11|2017| 11| Noviembre|
# |  2017-12|2017| 12| Diciembre|
# |  2018-01|2018| 01|     Enero|
# |  2018-02|2018| 02|   Febrero|
# |  2018-03|2018| 03|     Marzo|
# |  2018-04|2018| 04|     Abril|
# |  2018-05|2018| 05|      Mayo|
# |  2018-06|2018| 06|     Junio|
# |  2018-07|2018| 07|     Julio|
# |  2018-08|2018| 08|    Agosto|
# |  2018-09|2018| 09|Septiembre|
# |  2018-10|2018| 10|   Octubre|
# |  2018-11|2018| 11| Noviembre|
# |  2018-12|2018| 12| Diciembre|
# +---------+----+---+----------+

# %% [markdown]
# #### Dimensión empresa

# %%
def empresa(df_vuelos):
    
    df_empresa=df_vuelos.selectExpr('empresa')
    df_empresa = df_empresa.dropDuplicates(['empresa'])
    df_empresa = df_empresa.sort('empresa')
    df_empresa = df_empresa.withColumn("Key_Empresa",f.row_number().over(Window.orderBy(f.monotonically_increasing_id())))
    df_empresa = df_empresa.select('Key_Empresa','empresa')
    df_empresa.show(10)

    return df_empresa

df_empresa = empresa(df_vuelos)
# Out:
# +-----------+--------------------+
# |Key_Empresa|             empresa|
# +-----------+--------------------+
# |          1|"SERVICIO AÉREO R...|
# |          2|              21 AIR|
# |          3|                ABSA|
# |          4|ABX AIR INC SUCUR...|
# |          5| AER CARIBE LIMITADA|
# |          6|          AERO APOYO|
# |          7|AERO SERVICIOS ES...|
# |          8|AERO TAXI GUAYMAR...|
# |          9|AEROCHARTER ANDIN...|
# |         10|       AEROCOL S.A.S|
# +-----------+--------------------+
# only showing top 10 rows

# %% [markdown]
# #### Dimensión tipo de vuelo

# %%
def tipo_vuelo(df_vuelos):
    
    df_tipo = df_vuelos.selectExpr('tipo_vuelo')
    df_tipo = df_tipo.dropDuplicates(['tipo_vuelo'])
    df_tipo = df_tipo.withColumn("Key_Tipo",f.row_number().over(Window.orderBy(f.monotonically_increasing_id())))
    df_tipo = df_tipo.select('Key_Tipo','tipo_vuelo')
    
    df_tipo = df_tipo.withColumn('tipo', when(df_tipo.tipo_vuelo == 'T', lit('Taxi'))
                                                .when(df_tipo.tipo_vuelo == 'C', lit('Charter'))
                                                .when(df_tipo.tipo_vuelo == 'A', lit('Adicionales'))
                                                .when(df_tipo.tipo_vuelo == 'R', lit('Regular'))
                                  )
    
    df_tipo.show(10)

    return df_tipo

df_tipo = tipo_vuelo(df_vuelos)
# Out:
# +--------+----------+-----------+
# |Key_Tipo|tipo_vuelo|       tipo|
# +--------+----------+-----------+
# |       1|         T|       Taxi|
# |       2|         C|    Charter|
# |       3|         A|Adicionales|
# |       4|         R|    Regular|
# +--------+----------+-----------+

# %% [markdown]
# #### Dimensión tráfico

# %%
def trafico(df_vuelos):
    
    df_trafico = df_vuelos.select('trafico')
    df_trafico = df_trafico.dropDuplicates(['trafico'])
    df_trafico = df_trafico.withColumn("Key_Trafico",f.row_number().over(Window.orderBy(f.monotonically_increasing_id())))
    df_trafico = df_trafico.select('Key_Trafico','trafico')
    
    df_trafico = df_trafico.withColumn('trafico_nombre', when(df_trafico.trafico == 'N', lit('Nacional'))
                                                .when(df_trafico.trafico == 'I', lit('Internacional'))
                                                .when(df_trafico.trafico == 'E', lit('Externo'))
                                      )
    
    df_trafico.show(10)

    return df_trafico

df_trafico = trafico(df_vuelos)
# Out:
# +-----------+-------+--------------+
# |Key_Trafico|trafico|trafico_nombre|
# +-----------+-------+--------------+
# |          1|      N|      Nacional|
# |          2|      I| Internacional|
# +-----------+-------+--------------+

# %% [markdown]
# #### Dimensión aeropuertos

# %%
df_poblacion.show()
df_pib.show()
# Out:
# +---+---+--------------------+-------+
# |_c0| DP|        departamento|  Total|
# +---+---+--------------------+-------+
# |  0| 23|             Córdoba|1784783|
# |  1| 20|               Cesar|1200574|
# |  2| 52|              Nariño|1630592|
# |  3| 44|          La Guajira| 880560|
# |  4| 50|                Meta|1039722|
# |  5| 15|              Boyacá|1217376|
# |  6| 70|               Sucre| 904863|
# |  7|  5|           Antioquia|6407102|
# |  8| 54|  Norte de Santander|1491689|
# |  9| 88|Archipiélago de S...|  61280|
# | 10| 73|              Tolima|1330187|
# | 11| 94|             Guainía|  48114|
# | 12| 47|           Magdalena|1341746|
# | 13| 97|              Vaupés|  40797|
# | 14| 68|           Santander|2184837|
# | 15| 99|             Vichada| 107808|
# | 16| 95|            Guaviare|  82767|
# | 17| 11|        Bogotá, D.C.|7412566|
# | 18| 76|     Valle del Cauca|4475886|
# | 19| 86|            Putumayo| 348182|
# +---+---+--------------------+-------+
# only showing top 20 rows
#
# +--------+-------------+-----------+
# |DIVIPOLA|DEPARTAMENTOS|      Valor|
# +--------+-------------+-----------+
# |      91|     Amazonas|805.3779453|
# |       5|    Antioquia|153378.8609|
# |      81|       Arauca|5663.763473|
# |       8|    Atl�ntico|46667.51928|
# |      11|  Bogot� D.C.|273940.7724|
# |      13|      Bol�var|38372.81419|
# |      15|       Boyac�|28696.37935|
# |      17|       Caldas|17024.84447|
# |      18|      Caquet�|4300.620157|
# |      85|     Casanare|16382.43043|
# |      19|        Cauca|18777.29599|
# |      20|        Cesar|20796.48763|
# |      27|        Choc�| 4184.95422|
# |      23|      C�rdoba| 18293.5522|
# |      25| Cundinamarca|63422.50355|
# |      94|      Guain�a|409.9360516|
# |      95|     Guaviare| 831.299961|
# |      41|        Huila|17356.20479|
# |      44|   La Guajira|11147.43509|
# |      47|    Magdalena|14182.96419|
# +--------+-------------+-----------+
# only showing top 20 rows

# %%
df_aeropuertos_mundo.show()
df_aeropuertos_mundo.select([count(when(isnull(c), c)).alias(c) for c in df_aeropuertos_mundo.columns]).show(truncate = False, vertical = True)

aeropuertos_mundo = df_aeropuertos_mundo.dropna()

aeropuertos_mundo.show()
# Out:
# +----+----+--------------------+--------------+----------------+-------+-------+--------+
# |icao|iata|              nombre|        ciudad|            pais|altitud|latitud|longitud|
# +----+----+--------------------+--------------+----------------+-------+-------+--------+
# |AYGA| GKA|              GOROKA|        GOROKA|Papua New Guinea|   1610| -6.082| 145.392|
# |AYLA| LAE|                null|           LAE|Papua New Guinea|   null|    0.0|     0.0|
# |AYMD| MAG|              MADANG|        MADANG|Papua New Guinea|      7| -5.207| 145.789|
# |AYMH| HGU|         MOUNT HAGEN|   MOUNT HAGEN|Papua New Guinea|   1643| -5.826| 144.296|
# |AYNZ| LAE|              NADZAB|        NADZAB|Papua New Guinea|     73|  -6.57| 146.726|
# |AYPY| POM|PORT MORESBY JACK...|  PORT MORESBY|Papua New Guinea|     45| -9.443|  147.22|
# |AYRB| RAB|                null|        RABAUL|Papua New Guinea|   null|    0.0|     0.0|
# |AYWK| WWK| WEWAK INTERNATIONAL|         WEWAK|Papua New Guinea|      6| -3.584| 143.669|
# |BGAM|null|                null|  ANGMAGSSALIK|       Greenland|   null|    0.0|     0.0|
# |BGAS|null|                null|      ANGISSOQ|       Greenland|   null|    0.0|     0.0|
# |BGAT|null|                null|      APUTITEQ|       Greenland|   null|    0.0|     0.0|
# |BGBW| UAK|          NARSARSUAQ|  NARSSARSSUAQ|       Greenland|     35| 61.161| -45.427|
# |BGCH| JCH|                null|CHRISTIANSHAAB|       Greenland|   null|    0.0|     0.0|
# |BGCO|null|NERLERIT INAAT CO...|NERLERIT INAAT|       Greenland|     14| 70.739| -22.646|
# |BGDB|null|                null|      DANEBORG|       Greenland|   null|    0.0|     0.0|
# |BGDH|null|                null|  DANMARKSHAVN|       Greenland|   null|    0.0|     0.0|
# |BGDU|null|                null|        DUNDAS|       Greenland|   null|    0.0|     0.0|
# |BGEM| JEG|                null|   EGEDESMINDE|       Greenland|   null|    0.0|     0.0|
# |BGFD|null|                null|  FREDERIKSDAL|       Greenland|   null|    0.0|     0.0|
# |BGFH| JFR|                null| FREDERIKSHAAB|       Greenland|   null|    0.0|     0.0|
# +----+----+--------------------+--------------+----------------+-------+-------+--------+
# only showing top 20 rows
#
# -RECORD 0--------
#  icao     | 0
#  iata     | 5738
#  nombre   | 5105
#  ciudad   | 0
#  pais     | 0
#  altitud  | 5135
#  latitud  | 0
#  longitud | 0
#
# +----+----+--------------------+--------------+----------------+-------+-------+--------+
# |icao|iata|              nombre|        ciudad|            pais|altitud|latitud|longitud|
# +----+----+--------------------+--------------+----------------+-------+-------+--------+
# |AYGA| GKA|              GOROKA|        GOROKA|Papua New Guinea|   1610| -6.082| 145.392|
# |AYMD| MAG|              MADANG|        MADANG|Papua New Guinea|      7| -5.207| 145.789|
# |AYMH| HGU|         MOUNT HAGEN|   MOUNT HAGEN|Papua New Guinea|   1643| -5.826| 144.296|
# |AYNZ| LAE|              NADZAB|        NADZAB|Papua New Guinea|     73|  -6.57| 146.726|
# |AYPY| POM|PORT MORESBY JACK...|  PORT MORESBY|Papua New Guinea|     45| -9.443|  147.22|
# |AYWK| WWK| WEWAK INTERNATIONAL|         WEWAK|Papua New Guinea|      6| -3.584| 143.669|
# |BGBW| UAK|          NARSARSUAQ|  NARSSARSSUAQ|       Greenland|     35| 61.161| -45.427|
# |BGGH| GOH|                NUUK|      GODTHAAB|       Greenland|     87| 64.191| -51.678|
# |BGJN| JAV|          JACOBSHAVN|    JAKOBSHAVN|       Greenland|     34| 69.233| -51.067|
# |BGKK| KUS|             KULUSUK|       KULUSUK|       Greenland|     34| 65.583|  -37.15|
# |BGSF| SFJ|KANGERLUSSUAQ SON...|   SONDRESTROM|       Greenland|     51| 67.017| -50.689|
# |BGTL| THU|      THULE AIR BASE|         THULE|       Greenland|     77| 76.531| -68.703|
# |BIAR| AEY|            AKUREYRI|      AKUREYRI|         Iceland|      2|  65.66| -18.072|
# |BIEG| EGS|         EGILSSTADIR|   EGILSSTADIR|         Iceland|     24| 65.283| -14.401|
# |BIHN| HFN|        HORNAFJORDUR|          HOFN|         Iceland|      8| 64.296| -15.227|
# |BIHU| HZK|             HUSAVIK|       HUSAVIK|         Iceland|     14| 65.952| -17.426|
# |BIIS| IFJ|          ISAFJORDUR|    ISAFJORDUR|         Iceland|      3| 66.058| -23.135|
# |BIKF| KEF|        KEFLAVIK NAS|      KEFLAVIK|         Iceland|     53| 63.985| -22.606|
# |BIKP| OPA|            KOPASKER|      KOPASKER|         Iceland|      7| 66.314| -16.461|
# |BIPA| PFJ|      PATREKSFJORDUR|PATREKSFJORDUR|         Iceland|      4| 65.556| -23.965|
# +----+----+--------------------+--------------+----------------+-------+-------+--------+
# only showing top 20 rows

# %%
def aeropuertos_mundo(): 

    aeropuertos_mundo = df_aeropuertos_mundo.dropna()
    
    aeropuertos_mundo = aeropuertos_mundo.select('*').where(aeropuertos_mundo['pais']!= 'Colombia')
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'sigla' , aeropuertos_mundo['iata'])
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'categoria' , lit('Exterior') )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'ancho_pista' , lit(-1) )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'longitud_pista' , lit(-1) )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'Ano' , lit(2018) )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'Fecha_inicio' , lit('2018-01') )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'Fecha_expiracion' , lit('2018-12') )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'Estado' , lit('Vigente') )
    
    aeropuertos_mundo = aeropuertos_mundo.withColumn( 'Key_SocDem' , lit(999) )
    
    aeropuertos_mundo = aeropuertos_mundo.selectExpr('Key_SocDem' , 'sigla' , 'iata' , 'nombre', 'ciudad as municipio', 'pais','categoria','latitud','longitud', 'longitud_pista', 'ancho_pista', 'Ano', 'Fecha_inicio', 'Fecha_expiracion','Estado')
    
    aeropuertos_mundo2014 = aeropuertos_mundo.withColumn( 'Ano' , lit(2014) ).withColumn( 'Estado', lit('Vencido')).withColumn( 'Fecha_inicio' , lit('2014-01')).withColumn( 'Fecha_expiracion' , lit('2014-12') )
    aeropuertos_mundo2015 = aeropuertos_mundo.withColumn( 'Ano' , lit(2015) ).withColumn( 'Estado', lit('Vencido')).withColumn( 'Fecha_inicio' , lit('2015-01')).withColumn( 'Fecha_expiracion' , lit('2015-12') )
    aeropuertos_mundo2016 = aeropuertos_mundo.withColumn( 'Ano' , lit(2016) ).withColumn( 'Estado', lit('Vencido')).withColumn( 'Fecha_inicio' , lit('2016-01')).withColumn( 'Fecha_expiracion' , lit('2016-12') )
    aeropuertos_mundo2017 = aeropuertos_mundo.withColumn( 'Ano' , lit(2017) ).withColumn( 'Estado', lit('Vencido')).withColumn( 'Fecha_inicio' , lit('2017-01')).withColumn( 'Fecha_expiracion' , lit('2017-12') )
    
    aeropuertos_mundo = aeropuertos_mundo2014.union(aeropuertos_mundo)
    aeropuertos_mundo = aeropuertos_mundo2015.union(aeropuertos_mundo)
    aeropuertos_mundo = aeropuertos_mundo2016.union(aeropuertos_mundo)
    aeropuertos_mundo = aeropuertos_mundo2017.union(aeropuertos_mundo)
    
    aeropuertos_mundo.select('*').where(aeropuertos_mundo['sigla'] == 'MAD').show()
    
    
    print((aeropuertos_mundo.count(), len(aeropuertos_mundo.columns)))
    return aeropuertos_mundo
    


def socio_geografica():
    
    df_socio_geo = df_poblacion.join(df_pib, df_poblacion.DP == df_pib.DIVIPOLA, how='inner')
    df_socio_geo = df_socio_geo.selectExpr('departamento','Total as poblacion', 'Valor as PIB','DIVIPOLA')
    fila_internacionales = spark.createDataFrame([('Internacional',0,0,999)], df_socio_geo.columns)
    df_socio_geo = df_socio_geo.union(fila_internacionales) 
    df_socio_geo = df_socio_geo.withColumn("Key_SocDem",f.row_number().over(Window.orderBy(f.monotonically_increasing_id())))
    df_socio_geo = df_socio_geo.select("Key_SocDem",'departamento','poblacion', 'PIB','DIVIPOLA')
    
    df_socio_geo.toPandas().to_csv(PATH+'dim_socio_geo.csv')
    
    return None



def aeropuertos(df_aeropuertos,df_socio_geo,aeropuertos_mundo):
    
    aeropuertos_hist = df_aeropuertos
    
    aeropuertos_hist = aeropuertos_hist.withColumn('Fecha_inicio',when(aeropuertos_hist.Ano == 2014,lit('2010-01')).
                                                                  when(aeropuertos_hist.Ano == 2015,lit('2015-01')).
                                                                  when(aeropuertos_hist.Ano == 2016,lit('2016-01')).
                                                                  when(aeropuertos_hist.Ano == 2017,lit('2017-01')).
                                                                  when(aeropuertos_hist.Ano == 2018,lit('2018-01'))
                                                  )
    
    aeropuertos_hist = aeropuertos_hist.withColumn('Fecha_expiracion',when(aeropuertos_hist.Ano == 2014,lit('2014-12')).
                                                                      when(aeropuertos_hist.Ano == 2015,lit('2015-12')).
                                                                      when(aeropuertos_hist.Ano == 2016,lit('2016-01')).
                                                                      when(aeropuertos_hist.Ano == 2017,lit('2017-01')).
                                                                      when(aeropuertos_hist.Ano == 2018,lit('2018-01'))
                                                  )
    
    aeropuertos_hist = aeropuertos_hist.withColumn('Estado',when(aeropuertos_hist.Ano < 2018,lit('Vencido')).
                                                            when(aeropuertos_hist.Ano == 2018,lit('Vigente'))
                                                  )
    
    aeropuertos_hist = aeropuertos_hist.withColumn('pais', lit('Colombia'))                                              

    
    
    #Integración con Geografica
    
    
    
    aeropuertos_hist = aeropuertos_hist.join(df_socio_geo, aeropuertos_hist.gcd_departamento == df_socio_geo.DIVIPOLA, how='left')
    
    df_socio_geo = df_socio_geo.select('Key_SocDem', 'departamento' , 'poblacion' , 'PIB')
    
    aeropuertos_hist = aeropuertos_hist.selectExpr('Key_SocDem' , 'sigla' , 'iata', 'nombre','municipio' , 'pais' , 'categoria','latitud','longitud', 'longitud_pista', 'ancho_pista', 'Ano', 'Fecha_inicio', 'Fecha_expiracion','Estado')
    
    
    #Integración con Aeropuertos Internacionales
    
    aeropuertos_hist = aeropuertos_hist.union(aeropuertos_mundo)
    
    
    
    aeropuertos_hist.select('*').where(aeropuertos_hist['sigla']=='MAD').show()
    
    
    
       
    
    #Generación de llave 
    aeropuertos_hist = aeropuertos_hist.withColumn("Key_Aeropuertos",f.row_number().over(Window.orderBy(f.monotonically_increasing_id())))
    
    aeropuertos_hist = aeropuertos_hist.selectExpr('Key_Aeropuertos', 'Key_SocDem' , 'sigla' , 'iata', 'nombre','municipio' , 'pais' , 'categoria','latitud','longitud', 'longitud_pista', 'ancho_pista', 'Ano', 'Fecha_inicio', 'Fecha_expiracion','Estado')
   
    aeropuertos_hist.toPandas().to_csv(PATH+'dim_aeropuertos.csv')
    df_socio_geo.toPandas().to_csv(PATH+'dim_socio_geo.csv')
    df_socio_geo.show()
    
    return None

aeropuertos_mundo = aeropuertos_mundo()
socio_geografica()
df_socio_geo = spark.read.load(PATH+'dim_socio_geo.csv',format="csv", sep=",", inferSchema="true", header="true")
df_socio_geo.show(100)
aeropuertos(df_aeropuertos, df_socio_geo,aeropuertos_mundo)

aeropuertos_hist = spark.read.load(PATH+"dim_aeropuertos.csv",format="csv", sep=",", inferSchema="true", header="true")
aeropuertos_hist = aeropuertos_hist.drop('_c0')
aeropuertos_hist.select('*').show(10)
aeropuertos_hist.select('*').where(aeropuertos_hist['sigla']=='MAD').show(10)
aeropuertos_hist.select('Key_Aeropuertos','sigla','nombre','Key_SocDem').where(aeropuertos_hist['sigla']=='MAD').show(10)
# Out:
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |Key_SocDem|sigla|iata| nombre|municipio| pais|categoria|latitud|longitud|longitud_pista|ancho_pista| Ano|Fecha_inicio|Fecha_expiracion| Estado|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|            -1|         -1|2017|     2017-01|         2017-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|            -1|         -1|2016|     2016-01|         2016-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|            -1|         -1|2015|     2015-01|         2015-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|            -1|         -1|2014|     2014-01|         2014-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|            -1|         -1|2018|     2018-01|         2018-12|Vigente|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
#
# (14465, 15)
# +---+----------+--------------------+---------+-----------+--------+
# |_c0|Key_SocDem|        departamento|poblacion|        PIB|DIVIPOLA|
# +---+----------+--------------------+---------+-----------+--------+
# |  0|         1|             Córdoba|  1784783| 18293.5522|      23|
# |  1|         2|               Cesar|  1200574|20796.48763|      20|
# |  2|         3|              Nariño|  1630592|15998.09556|      52|
# |  3|         4|          La Guajira|   880560|11147.43509|      44|
# |  4|         5|                Meta|  1039722|38271.66587|      50|
# |  5|         6|              Boyacá|  1217376|28696.37935|      15|
# |  6|         7|               Sucre|   904863|8736.205279|      70|
# |  7|         8|           Antioquia|  6407102|153378.8609|       5|
# |  8|         9|  Norte de Santander|  1491689|16339.10553|      54|
# |  9|        10|Archipiélago de S...|    61280|1640.638037|      88|
# | 10|        11|              Tolima|  1330187|22407.29796|      73|
# | 11|        12|             Guainía|    48114|409.9360516|      94|
# | 12|        13|           Magdalena|  1341746|14182.96419|      47|
# | 13|        14|              Vaupés|    40797| 303.094594|      97|
# | 14|        15|           Santander|  2184837|69248.47972|      68|
# | 15|        16|             Vichada|   107808|683.3854899|      99|
# | 16|        17|            Guaviare|    82767| 831.299961|      95|
# | 17|        18|        Bogotá, D.C.|  7412566|273940.7724|      11|
# | 18|        19|     Valle del Cauca|  4475886|103097.3193|      76|
# | 19|        20|            Putumayo|   348182| 4059.01714|      86|
# | 20|        21|             Bolívar|  2070110|38372.81419|      13|
# | 21|        22|               Cauca|  1464488|18777.29599|      19|
# | 22|        23|              Caldas|   998255|17024.84447|      17|
# | 23|        24|            Casanare|   420504|16382.43043|      85|
# | 24|        25|               Chocó|   534826| 4184.95422|      27|
# | 25|        26|           Atlántico|  2535517|46667.51928|       8|
# | 26|        27|              Arauca|   262174|5663.763473|      81|
# | 27|        28|            Amazonas|    76589|805.3779453|      91|
# | 28|        29|             Caquetá|   401849|4300.620157|      18|
# | 29|        30|           Risaralda|   943401|17125.25112|      66|
# | 30|        31|               Huila|  1100386|17356.20479|      41|
# | 31|        32|        Cundinamarca|  2919060|63422.50355|      25|
# | 32|        33|             Quindio|   539904|8573.428125|      63|
# | 33|        34|       Internacional|        0|        0.0|     999|
# +---+----------+--------------------+---------+-----------+--------+
#
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |Key_SocDem|sigla|iata| nombre|municipio| pais|categoria|latitud|longitud|longitud_pista|ancho_pista| Ano|Fecha_inicio|Fecha_expiracion| Estado|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2017|     2017-01|         2017-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2016|     2016-01|         2016-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2015|     2015-01|         2015-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2014|     2014-01|         2014-12|Vencido|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2018|     2018-01|         2018-12|Vigente|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
#
# +----------+--------------------+---------+-----------+
# |Key_SocDem|        departamento|poblacion|        PIB|
# +----------+--------------------+---------+-----------+
# |         1|             Córdoba|  1784783| 18293.5522|
# |         2|               Cesar|  1200574|20796.48763|
# |         3|              Nariño|  1630592|15998.09556|
# |         4|          La Guajira|   880560|11147.43509|
# |         5|                Meta|  1039722|38271.66587|
# |         6|              Boyacá|  1217376|28696.37935|
# |         7|               Sucre|   904863|8736.205279|
# |         8|           Antioquia|  6407102|153378.8609|
# |         9|  Norte de Santander|  1491689|16339.10553|
# |        10|Archipiélago de S...|    61280|1640.638037|
# |        11|              Tolima|  1330187|22407.29796|
# |        12|             Guainía|    48114|409.9360516|
# |        13|           Magdalena|  1341746|14182.96419|
# |        14|              Vaupés|    40797| 303.094594|
# |        15|           Santander|  2184837|69248.47972|
# |        16|             Vichada|   107808|683.3854899|
# |        17|            Guaviare|    82767| 831.299961|
# |        18|        Bogotá, D.C.|  7412566|273940.7724|
# |        19|     Valle del Cauca|  4475886|103097.3193|
# |        20|            Putumayo|   348182| 4059.01714|
# +----------+--------------------+---------+-----------+
# only showing top 20 rows
#
# +---------------+----------+-----+----+--------------------+-------------------+--------+-------------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |Key_Aeropuertos|Key_SocDem|sigla|iata|              nombre|          municipio|    pais|    categoria|latitud|longitud|longitud_pista|ancho_pista| Ano|Fecha_inicio|Fecha_expiracion| Estado|
# +---------------+----------+-----+----+--------------------+-------------------+--------+-------------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |              1|        32|  7HE|null|GUACHARACAS (COLO...|            Beltrán|Colombia|    Aeródromo| 4.7371|-74.8021|          27.0|        0.0|2015|     2015-01|         2015-12|Vencido|
# |              2|        24|  7IA|null|              MURIBA|               Maní|Colombia|    Aeródromo| 4.5809|-72.2551|         704.0|       51.0|2015|     2015-01|         2015-12|Vencido|
# |              3|        24|  9DA|null|            BALMORAL|               Maní|Colombia|    Aeródromo| 4.8864|-72.3439|         904.0|        9.0|2015|     2015-01|         2015-12|Vencido|
# |              4|         2|  AGY|null|BASE PRINCIPAL CELTA|          Aguachica|Colombia|    Aeródromo| 8.2002|-73.6313|        1550.0|        7.0|2015|     2015-01|         2015-12|Vencido|
# |              5|         2|  BEC|null|            BECERRIL|           Becerril|Colombia|    Aeródromo| 9.6628|-73.2744|          52.0|       91.0|2015|     2015-01|         2015-12|Vencido|
# |              6|        21|  CTG| CTG|        RAFAEL NUÑEZ|Cartagena de Indias|Colombia|Internacional| 10.442|-75.5123|         424.0|        6.0|2015|     2015-01|         2015-12|Vencido|
# |              7|        15|  ZPS| AZT|GUILLERMO GOMEZ O...|           Zapatoca|Colombia|    Aeródromo| 6.7674|-73.2846|        1465.0|       48.0|2015|     2015-01|         2015-12|Vencido|
# |              8|         5|  9BK|null|              JULIAN|           Cabuyaro|Colombia|    Aeródromo| 4.2711|-72.9869|        1262.0|       10.0|2017|     2017-01|         2017-01|Vencido|
# |              9|         5|  9BX|null|     LA ESTRELLA-CA.|         San Martín|Colombia|    Aeródromo| 3.4802|-73.3276|         988.0|      169.0|2018|     2018-01|         2018-01|Vigente|
# |             10|         1|  9AA|null|       BONAIRE  - CA|             Ayapel|Colombia|    Aeródromo| 8.2851|-75.0505|         883.0|        1.0|2018|     2018-01|         2018-01|Vigente|
# +---------------+----------+-----+----+--------------------+-------------------+--------+-------------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# only showing top 10 rows
#
# +---------------+----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |Key_Aeropuertos|Key_SocDem|sigla|iata| nombre|municipio| pais|categoria|latitud|longitud|longitud_pista|ancho_pista| Ano|Fecha_inicio|Fecha_expiracion| Estado|
# +---------------+----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
# |           2821|       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2017|     2017-01|         2017-12|Vencido|
# |           5714|       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2016|     2016-01|         2016-12|Vencido|
# |           8607|       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2015|     2015-01|         2015-12|Vencido|
# |          11500|       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2014|     2014-01|         2014-12|Vencido|
# |          14393|       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2018|     2018-01|         2018-12|Vigente|
# +---------------+----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+
#
# +---------------+-----+-------+----------+
# |Key_Aeropuertos|sigla| nombre|Key_SocDem|
# +---------------+-----+-------+----------+
# |           2821|  MAD|BARAJAS|       999|
# |           5714|  MAD|BARAJAS|       999|
# |           8607|  MAD|BARAJAS|       999|
# |          11500|  MAD|BARAJAS|       999|
# |          14393|  MAD|BARAJAS|       999|
# +---------------+-----+-------+----------+

# %% [markdown]
# #### Tabla de hechos vuelos

# %%
def hechos_vuelos(aeropuertos_hist):
    
    
    
    df_hechos_vuelos = df_vuelos.withColumn("mes", f.format_string("%02d","mes"))
    df_hechos_vuelos = df_hechos_vuelos.select(concat_ws('-','ano','mes').alias('Key_Fecha'),'ano' ,'origen','destino','tipo_vuelo', 'trafico','empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')
        
   
   #Se crean llaves con ANO+Sigla de aeropuertos tanto en df de Aeropuertos, como en df de vuelos (para origen y destino) 
   #para poder cruzar los DF.

    aeropuertos_hist = aeropuertos_hist.select(concat_ws('-','Ano','sigla').alias('Key_Ano_Sigla'),'Key_Aeropuertos', 'Key_SocDem' , 'sigla' , 'iata', 'nombre','municipio', 'categoria','latitud','longitud', 'longitud_pista', 'ancho_pista', 'Ano', 'Fecha_inicio', 'Fecha_expiracion','Estado')
   
    
    df_hechos_vuelos = df_hechos_vuelos.withColumn('Key_Ano_Origen' , when(df_hechos_vuelos.ano < 2015, concat_ws('-',lit('2014'),'origen')).
                                                                      when(df_hechos_vuelos.ano == 2015, concat_ws('-',lit('2015'),'origen')).
                                                                      when(df_hechos_vuelos.ano == 2016, concat_ws('-',lit('2016'),'origen')).
                                                                      when(df_hechos_vuelos.ano == 2017, concat_ws('-',lit('2017'),'origen')).
                                                                      when(df_hechos_vuelos.ano == 2018, concat_ws('-',lit('2018'),'origen'))
                                                   )
    
    
    
    df_hechos_vuelos = df_hechos_vuelos.withColumn('Key_Ano_Destino', when(df_hechos_vuelos.ano < 2015, concat_ws('-',lit('2014'),'destino')).
                                                                      when(df_hechos_vuelos.ano == 2015, concat_ws('-',lit('2015'),'destino')).
                                                                      when(df_hechos_vuelos.ano == 2016, concat_ws('-',lit('2016'),'destino')).
                                                                      when(df_hechos_vuelos.ano == 2017, concat_ws('-',lit('2017'),'destino')).
                                                                      when(df_hechos_vuelos.ano == 2018, concat_ws('-',lit('2018'),'destino'))
                                                   )
    
    df_hechos_vuelos.show()
    
    df_hechos_vuelos = df_hechos_vuelos.join(aeropuertos_hist, df_hechos_vuelos.Key_Ano_Origen==aeropuertos_hist.Key_Ano_Sigla, how='left')
    df_hechos_vuelos = df_hechos_vuelos.selectExpr('Key_Ano_Destino','Key_Fecha', 'Key_Aeropuertos as Key_Origen','destino','tipo_vuelo', 'trafico', 'empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')
    
    df_hechos_vuelos = df_hechos_vuelos.join(aeropuertos_hist, df_hechos_vuelos.Key_Ano_Destino==aeropuertos_hist.Key_Ano_Sigla, how='left')
    df_hechos_vuelos = df_hechos_vuelos.selectExpr('Key_Fecha', 'Key_Origen','Key_Aeropuertos as Key_Destino','tipo_vuelo', 'trafico','empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')
                                                                          
    df_hechos_vuelos = df_hechos_vuelos.join(df_tipo, on = 'tipo_vuelo', how='left')
    df_hechos_vuelos = df_hechos_vuelos.selectExpr('Key_Fecha', 'Key_Origen', 'Key_Destino','Key_Tipo','trafico', 'empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')

    df_hechos_vuelos = df_hechos_vuelos.join(df_trafico, on = 'trafico', how='left')
    df_hechos_vuelos = df_hechos_vuelos.selectExpr('Key_Fecha', 'Key_Origen', 'Key_Destino','Key_Tipo','Key_Trafico','empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')                                              
                                                   
    df_hechos_vuelos = df_hechos_vuelos.join(df_empresa, on = 'empresa', how='left')
    df_hechos_vuelos = df_hechos_vuelos.selectExpr('Key_Fecha', 'Key_Origen', 'Key_Destino','Key_Tipo','Key_Trafico','Key_Empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')
        
    #Se elimna la información de los vuelos que ocurren antes de 2014 pero el aeropuerto no existe en la actualización de 2014 (p.ej BAQ)        
    df_hechos_vuelos = df_hechos_vuelos.na.drop(subset=['Key_Origen','Key_Destino'])
    
    #Se incluye la llave principal.
    df_hechos_vuelos = df_hechos_vuelos.withColumn("id",f.row_number().over(Window.orderBy(f.monotonically_increasing_id())))
    
    df_hechos_vuelos = df_hechos_vuelos.select('id','Key_Fecha', 'Key_Origen', 'Key_Destino','Key_Tipo','Key_Trafico','Key_Empresa','vuelos','sillas','carga_ofrecida','pasajeros','carga_bordo')
    
    
    return df_hechos_vuelos



df_hechos_vuelos = hechos_vuelos(aeropuertos_hist)
df_hechos_vuelos.show(truncate=False)
print((df_hechos_vuelos.count(), len(df_hechos_vuelos.columns)))
# Out:
# +---------+----+------+-------+----------+-------+--------------------+------+------+--------------+---------+-----------+--------------+---------------+
# |Key_Fecha| ano|origen|destino|tipo_vuelo|trafico|             empresa|vuelos|sillas|carga_ofrecida|pasajeros|carga_bordo|Key_Ano_Origen|Key_Ano_Destino|
# +---------+----+------+-------+----------+-------+--------------------+------+------+--------------+---------+-----------+--------------+---------------+
# |  2016-04|2016|   IBE|    EOH|         T|      N|AEROCHARTER ANDIN...|     1|     0|           0.0|        0|        0.0|      2016-IBE|       2016-EOH|
# |  2010-04|2010|   MVP|    MIS|         T|      N|AEROLINEAS LLANER...|     2|     0|           0.0|        0|       35.0|      2014-MVP|       2014-MIS|
# |  2014-02|2014|   EOH|    APO|         T|      N|PACIFICA DE AVIAC...|    10|     0|           0.0|       20|     1000.0|      2014-EOH|       2014-APO|
# |  2010-05|2010|   BOG|    EYP|         R|      N|         EASYFLY S.A|   149|  3407|           0.0|     2391|        0.0|      2014-BOG|       2014-EYP|
# |  2012-10|2012|   CLO|    MDE|         R|      N|             AVIANCA|    58|  8699|      486238.0|     5976|     1693.0|      2014-CLO|       2014-MDE|
# |  2018-03|2018|   MDE|    SMR|         R|      N|               AIRES|     7|  1218|      124132.0|     1102|      226.0|      2018-MDE|       2018-SMR|
# |  2017-11|2017|   LPR|    PIM|         T|      N|           NO FIGURA|     1|     0|           0.0|        1|      210.0|      2017-LPR|       2017-PIM|
# |  2018-12|2018|   CTG|    BOG|         T|      N|      HELISTAR S.A.S|     1|     0|           0.0|        0|        0.0|      2018-CTG|       2018-BOG|
# |  2014-01|2014|   CTG|    BOG|         A|      N|             AVIANCA|     1|   120|        8724.0|       92|        0.0|      2014-CTG|       2014-BOG|
# |  2018-02|2018|   LMC|    VVC|         T|      N|AEROLINEAS LLANER...|     1|     0|           0.0|        3|        0.0|      2018-LMC|       2018-VVC|
# |  2018-09|2018|   EOH|    MLR|         T|      N|             HELICOL|     1|     0|           0.0|       14|        0.0|      2018-EOH|       2018-MLR|
# |  2018-03|2018|   BAQ|    EOH|         T|      N|             HELICOL|     2|     0|           0.0|        6|        0.0|      2018-BAQ|       2018-EOH|
# |  2012-10|2012|   LMC|    VVC|         R|      N|               SELVA|     4|    76|       20000.0|        8|     1885.0|      2014-LMC|       2014-VVC|
# |  2018-07|2018|   BOG|    MDE|         R|      N|                 LAS|     2|     0|       48000.0|        0|    26325.0|      2018-BOG|       2018-MDE|
# |  2012-02|2012|   BGI|    BOG|         R|      I|    TAMPA CARGO S.A.|     2|     0|       90719.0|        0|    37586.0|      2014-BGI|       2014-BOG|
# |  2018-03|2018|   EOH|    BSC|         T|      N|        LOS HALCONES|     1|     0|           0.0|        2|        0.0|      2018-EOH|       2018-BSC|
# |  2014-03|2014|   EOH|    BOG|         T|      N|VIAS AEREAS NACIO...|     1|     0|           0.0|        1|        0.0|      2014-EOH|       2014-BOG|
# |  2015-02|2015|   VVC|    MAP|         T|      N|            ARO LTDA|     4|     0|           0.0|       13|      760.0|      2015-VVC|       2015-MAP|
# |  2011-04|2011|   MVP|    SJE|         R|      N|        AIR COLOMBIA|     6|     0|       18000.0|        0|    12500.0|      2014-MVP|       2014-SJE|
# |  2017-03|2017|   EOH|    TLU|         R|      N|AEROLINEA DE ANTI...|     9|   288|       21652.0|      139|       97.0|      2017-EOH|       2017-TLU|
# +---------+----+------+-------+----------+-------+--------------------+------+------+--------------+---------+-----------+--------------+---------------+
# only showing top 20 rows
#
# +---+---------+----------+-----------+--------+-----------+-----------+------+------+--------------+---------+-----------+
# |id |Key_Fecha|Key_Origen|Key_Destino|Key_Tipo|Key_Trafico|Key_Empresa|vuelos|sillas|carga_ofrecida|pasajeros|carga_bordo|
# +---+---------+----------+-----------+--------+-----------+-----------+------+------+--------------+---------+-----------+
# |1  |2010-05  |155       |51         |4       |1          |75         |149   |3407  |0.0           |2391     |0.0        |
# |2  |2018-12  |83        |176        |1       |1          |88         |1     |0     |0.0           |0        |0.0        |
# |3  |2014-01  |1251      |155        |3       |1          |49         |1     |120   |8724.0        |92       |0.0        |
# |4  |2012-02  |12612     |155        |4       |2          |145        |2     |0     |90719.0       |0        |37586.0    |
# |5  |2016-12  |4991      |1229       |1       |1          |41         |1     |0     |0.0           |0        |0.0        |
# |6  |2016-02  |6848      |1090       |4       |2          |105        |1     |0     |24000.0       |0        |2080.0     |
# |7  |2018-02  |176       |15322      |4       |2          |120        |1     |162   |18170.0       |117      |0.0        |
# |8  |2010-03  |11242     |155        |4       |2          |65         |62    |7688  |35000.0       |5011     |32204.0    |
# |9  |2011-07  |155       |1201       |1       |1          |108        |1     |0     |0.0           |2        |0.0        |
# |10 |2018-07  |176       |217        |4       |1          |36         |103   |17900 |1869283.0     |13659    |25266.0    |
# |11 |2018-10  |13670     |1075       |1       |1          |20         |2     |0     |0.0           |2        |22.0       |
# |12 |2016-12  |1316      |1049       |1       |1          |139        |1     |0     |0.0           |0        |0.0        |
# |13 |2012-04  |1297      |142        |1       |1          |108        |2     |0     |0.0           |10       |0.0        |
# |14 |2012-06  |357       |155        |4       |1          |49         |141   |7332  |228047.0      |5183     |320.0      |
# |15 |2011-06  |11882     |155        |4       |2          |21         |30    |3660  |95160.0       |3018     |3318.0     |
# |16 |2013-09  |555       |392        |1       |1          |87         |2     |0     |0.0           |7        |30.0       |
# |17 |2018-04  |176       |1138       |1       |1          |130        |2     |0     |0.0           |17       |80.0       |
# |18 |2012-06  |973       |205        |1       |1          |122        |1     |0     |0.0           |9        |0.0        |
# |19 |2018-10  |14816     |176        |4       |2          |67         |2     |248   |11422.0       |193      |15.0       |
# |20 |2017-08  |3915      |1009       |4       |2          |24         |18    |2556  |102798.0      |2308     |0.0        |
# +---+---------+----------+-----------+--------+-----------+-----------+------+------+--------------+---------+-----------+
# only showing top 20 rows
#
# (85213, 12)

# %%
df_hechos_vuelos.select('*').where(df_hechos_vuelos['Key_Origen']==2821).show(100)
aeropuertos_hist.select('*').where(aeropuertos_hist['Key_Aeropuertos']==2821).show(100)
aeropuertos_hist.select('*').where(aeropuertos_hist['sigla']=='MAD').show(100)
# Out:
# +-----+---------+----------+-----------+--------+-----------+-----------+------+------+--------------+---------+-----------+
# |   id|Key_Fecha|Key_Origen|Key_Destino|Key_Tipo|Key_Trafico|Key_Empresa|vuelos|sillas|carga_ofrecida|pasajeros|carga_bordo|
# +-----+---------+----------+-----------+--------+-----------+-----------+------+------+--------------+---------+-----------+
# | 5542|  2017-02|      2821|       1009|       4|          2|         32|    28|  8288|      221200.0|     4562|   129169.0|
# |20502|  2017-03|      2821|       1221|       4|          2|         49|    31|  7555|      887381.0|     4082|    74506.0|
# |41408|  2017-06|      2821|       1009|       4|          2|         32|    30|  8880|      255000.0|     6648|   106564.0|
# +-----+---------+----------+-----------+--------+-----------+-----------+------+------+--------------+---------+-----------+
#
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+---------------+
# |Key_SocDem|sigla|iata| nombre|municipio| pais|categoria|latitud|longitud|longitud_pista|ancho_pista| Ano|Fecha_inicio|Fecha_expiracion| Estado|Key_Aeropuertos|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+---------------+
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2017|     2017-01|         2017-12|Vencido|           2821|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+---------------+
#
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+---------------+
# |Key_SocDem|sigla|iata| nombre|municipio| pais|categoria|latitud|longitud|longitud_pista|ancho_pista| Ano|Fecha_inicio|Fecha_expiracion| Estado|Key_Aeropuertos|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+---------------+
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2017|     2017-01|         2017-12|Vencido|           2821|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2016|     2016-01|         2016-12|Vencido|           5714|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2015|     2015-01|         2015-12|Vencido|           8607|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2014|     2014-01|         2014-12|Vencido|          11500|
# |       999|  MAD| MAD|BARAJAS|   MADRID|Spain| Exterior| 40.472|  -3.561|          -1.0|       -1.0|2018|     2018-01|         2018-12|Vigente|          14393|
# +----------+-----+----+-------+---------+-----+---------+-------+--------+--------------+-----------+----+------------+----------------+-------+---------------+

# %%
#Se escriben los archivos.

df_hechos_vuelos.toPandas().to_csv(PATH+'hechos_vuelos.csv')
df_trafico.toPandas().to_csv(PATH+'dim_trafico.csv')
df_tipo.toPandas().to_csv(PATH+'dim_tipo.csv')
df_fecha.toPandas().to_csv(PATH+'dim_fecha.csv')
df_empresa.toPandas().to_csv(PATH+'dim_empresa.csv')
aeropuertos_hist.toPandas().to_csv(PATH+'dim_aeropuertos.csv')
